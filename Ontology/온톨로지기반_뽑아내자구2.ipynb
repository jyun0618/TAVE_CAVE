# %%
# 구글 드라이브 연동
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 필요한 라이브러리 설치
# !pip install rdflib
# !pip install sentence-transformers
# !pip install torch
# !pip install tqdm
# Out:
# Collecting rdflib
#   Downloading rdflib-7.1.4-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from rdflib) (3.2.3)
# Downloading rdflib-7.1.4-py3-none-any.whl (565 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 565.1/565.1 kB 33.7 MB/s eta 0:00:00
# Installing collected packages: rdflib
# Successfully installed rdflib-7.1.4
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.11/dist-packages (4.1.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.52.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (2.6.0+cu124)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (1.15.3)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (0.33.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (11.2.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers) (4.14.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.1.5)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.11.0->sentence-transformers)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2025.6.15)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 126.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 96.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 65.3 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.8 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.3 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 110.1 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)

# %%
# 온톨리지 파일에서 개념 추출
from rdflib import Graph

# 온톨로지 OWL 파일 경로
ontology_path = "/content/drive/MyDrive/문화data/Refresh.rdf"

g = Graph()
g.parse(ontology_path)

# 온톨로지 클래스(개념) 추출
concepts = []
for s, p, o in g.triples((None, None, None)):
    if p.endswith('type') and o.endswith('Class'):
        # 클래스 이름만 추출
        class_name = s.split('#')[-1]
        concepts.append(class_name)

print('온톨로지 개념:', concepts)
# Out:
# 온톨로지 개념: ['에너지_충전', '공감됨', '공감_및_위로', '위로와_응원', '자극_받음', '활력_회복', '코믹함', '기분전환', '즐거움', '이해받는_느낌', '현실을_잊음', '신선함', '마음의_안식', '긍정적_에너지', '내_이야기를_보는_듯함', '포근함', '재미', '스트레스_해소', '다시_힘을_얻음', '시간_가는_줄_모름', '마음이_가벼워짐', '상쾌함', '위로받음', '활력_얻음', '희망_및_용기', '빠져들었음', '웃음', '정서적_안정', '몰입/집중', '기분이_좋아짐', '잔잔함', '안도감', '일상에서_벗어남', '새로움/자극', '유쾌함', '색다른_이야기', '용기_얻음', '울음/감정_해소', '평온함']

# %%
# 리뷰 데이터가 줄마다 한 리뷰씩 저장된 txt 파일이라고 가정
review_path = "/content/drive/MyDrive/문화data/all_watcha_reviews(top 400).txt"

with open(review_path, 'r', encoding='utf-8') as f:
    reviews = [line.strip() for line in f.readlines()]

print('리뷰 샘플:', reviews[:5])
# Out:
# 리뷰 샘플: ['[(아는 건 별로 없지만) 가족입니다] https://pedia.watcha.com/ko-KR/contents/tPeWKYo', '“가족은 남이 찾지 못하는 급소를 너무 잘 알고 있다', '언제든 강력한 한방을 날릴 수 있다”', '', '-9화 은희 대사중']

# %%
# BGE-M3 임베딩 모델 로딩
from sentence_transformers import SentenceTransformer

# BGE-M3 모델명 (HuggingFace Hub 기준)
model_name = 'BAAI/bge-m3'
model = SentenceTransformer(model_name)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/123 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/54.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/687 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.27G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.27G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/444 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/964 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/191 [00:00<?, ?B/s]

# %%
# 온톨로지 개념 임베딩
concept_embeddings = model.encode(concepts, normalize_embeddings=True)

# 테스트용 리뷰 일부만 샘플링 (예: 100개)
sample_reviews = reviews[:100]
review_embeddings = model.encode(sample_reviews, normalize_embeddings=True)

# %%
# 코싸인 유사도 계산 및 필터링
import torch
import numpy as np

# 임계값 설정 (예: 0.5 이상)
threshold = 0.7

# 코사인 유사도 계산
filtered_reviews = []
for idx, emb in enumerate(review_embeddings):
    # 각 리뷰와 모든 온톨로지 개념 임베딩의 유사도 계산
    sims = np.dot(concept_embeddings, emb)
    if np.max(sims) >= threshold:
        filtered_reviews.append(sample_reviews[idx])

print('필터링된 리뷰:', filtered_reviews[:5])
# Out:
# 필터링된 리뷰: []

# %% [markdown]
# ### 전체 다시 돌리기

# %%
import csv

# 파일 경로 설정
csv_file = '/content/drive/MyDrive/문화data/filtered_watcha_reviews_non_metro.csv'    # 변환할 CSV 파일명
txt_file = '/content/drive/MyDrive/문화data/filtered_watcha_reviews_non_metro.txt'   # 저장할 TXT 파일명

# CSV 읽고 TXT로 저장
with open(csv_file, 'r', encoding='utf-8') as infile, open(txt_file, 'w', encoding='utf-8') as outfile:
    reader = csv.reader(infile)
    for row in reader:
        # 쉼표 대신 탭(\t)으로 구분하여 저장 (원하는 구분자로 변경 가능)
        outfile.write('\t'.join(row) + '\n')

print('변환이 완료되었습니다!')
# Out:
# 변환이 완료되었습니다!

# %%
# 1. 온톨로지 파일에서 개념 추출 (rdflib 그대로 사용)
from rdflib import Graph

ontology_path = "/content/drive/MyDrive/문화data/Refresh.rdf"
g = Graph()
g.parse(ontology_path)

concepts = []
for s, p, o in g.triples((None, None, None)):
    if p.endswith('type') and o.endswith('Class'):
        class_name = s.split('#')[-1]
        concepts.append(class_name)

print('온톨로지 개념 수:', len(concepts))
# Out:
# 온톨로지 개념 수: 39

# %%
# 2. 전체 리뷰 데이터 불러오기
review_path = "/content/drive/MyDrive/문화data/filtered_watcha_reviews_non_metro.txt"
with open(review_path, 'r', encoding='utf-8') as f:
    reviews = [line.strip() for line in f if line.strip()]

print('전체 리뷰 수:', len(reviews))
# Out:
# 전체 리뷰 수: 19426

# %%
reviews = []
with open(review_path, 'r', encoding='utf-8') as f:
    # 첫 줄은 헤더이므로 건너뜀
    next(f)
    for line in f:
        parts = line.strip().split('\t')
        if len(parts) >= 3:
            title = parts[0]
            review_text = parts[2]
            review_block = f"[{title}]\n{review_text}"
            reviews.append(review_block)

print('리뷰 샘플:', reviews[:5])
# Out:
# 리뷰 샘플: ['[(아는 건 별로 없지만) 가족입니다]\n“가족은 남이 찾지 못하는 급소를 너무 잘 알고 있다 언제든 강력한 한방을 날릴 수 있다”', '[(아는 건 별로 없지만) 가족입니다]\n첫째는 첫째같고 둘째는 둘째같다 ㅋㅋ 추자현 배우 보면서 계속 연기 잘한다고 감탄함 잘생겼음. 완벽하고 멋있다.', '[(아는 건 별로 없지만) 가족입니다]\n오랜만에 느껴지는 명드의 냄새', '[(아는 건 별로 없지만) 가족입니다]\n스포일러가 있어요!!보기', '[(아는 건 별로 없지만) 가족입니다]\n엔딩 크레딧마저 완벽했다.']

# %%
# 3. BGE-M3 임베딩 모델 로딩
from sentence_transformers import SentenceTransformer
model_name = 'BAAI/bge-m3'
model = SentenceTransformer(model_name)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/123 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/54.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/687 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.27G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.27G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/444 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/964 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/191 [00:00<?, ?B/s]

# %%
# 4. 온톨로지 개념 임베딩
concept_embeddings = model.encode(concepts, normalize_embeddings=True)

# %%
import numpy as np
from tqdm import tqdm
import torch
import gc

threshold = 0.6
batch_size = 64
internal_encode_batch = 4

def extract_review_text(review_block):
    lines = review_block.split('\n')
    return '\n'.join(lines[1:]).strip()

review_texts = [extract_review_text(r) for r in reviews]

filtered_reviews = []

for i in tqdm(range(0, len(reviews), batch_size)):
    batch_texts = review_texts[i:i+batch_size]
    batch_blocks = reviews[i:i+batch_size]

    try:
        # GPU 시도
        batch_embeddings = model.encode(
            batch_texts,
            normalize_embeddings=True,
            batch_size=internal_encode_batch,
            device='cuda'
        )
    except RuntimeError as e:
        print(f"\n🚨 GPU 메모리 부족! CPU로 전환 중... ({i}~{i+batch_size})")
        torch.cuda.empty_cache()
        gc.collect()  # Python 메모리 정리

        # CPU fallback
        batch_embeddings = model.encode(
            batch_texts,
            normalize_embeddings=True,
            batch_size=internal_encode_batch,
            device='cpu'
        )

    # 유사도 계산
    sims = np.dot(batch_embeddings, concept_embeddings.T)
    for j, sim_row in enumerate(sims):
        if np.max(sim_row) >= threshold:
            filtered_reviews.append(batch_blocks[j])

    # 중간 중간 GPU 메모리 해제
    torch.cuda.empty_cache()
    gc.collect()

# 결과 확인
print('✅ 필터링된 리뷰 샘플:', filtered_reviews[:2])
print('✅ 필터링된 리뷰 수:', len(filtered_reviews))
# Out:
# 100%|██████████| 304/304 [09:55<00:00,  1.96s/it]
# ✅ 필터링된 리뷰 샘플: ['[(아는 건 별로 없지만) 가족입니다]\n흔하디 흔한 자극적 전개가 아닐까싶었지만 볼수록 오묘하고 생각하게 만드는 이야기들이 흥미롭다', '[(아는 건 별로 없지만) 가족입니다]\n가족은 같이 살아온 세월이다.']
# ✅ 필터링된 리뷰 수: 982

# %%
filtered_reviews
# Out:
# ['[(아는 건 별로 없지만) 가족입니다]\n흔하디 흔한 자극적 전개가 아닐까싶었지만 볼수록 오묘하고 생각하게 만드는 이야기들이 흥미롭다',
#  '[(아는 건 별로 없지만) 가족입니다]\n가족은 같이 살아온 세월이다.',
#  '[1%의 어떤것]\n음.',
#  '[18 어게인]\n뭐 유치하지만 재밌다 가볍게 보기좋다 드라마가 재밌음댔지 갑자기 교훈 +감동+ 억지 눈물만 아님 좋겠다',
#  '[18 어게인]\n눈물이 났다 왠지 모르게…',
#  '[18 어게인]\n기분 좋아지는 휴먼 판타지 이도현의 발견, 찐 농구 장면 인정~',
#  '[365: 운명을 거스르는 1년]\n지나온 어제보다 오늘을 믿고, 알 수 없는 내일을 향해 용기를 내는 것. 주어진 오늘에 최선을 다해야 할 이유가 여기에 있다.',
#  '[365: 운명을 거스르는 1년]\n참신 신선 군더더기없는 스토리...',
#  '[49일]\n말로 다하지 않아도 느껴지는 진심.  서서히 스며와 나마저도 알지 못한 시간 동안 지그시 바라봐주던 따스한 마음.',
#  '[가면]\n메이 보려고 봣어요',
#  '[가면]\n재미없어요. 2023. 3. 4.',
#  '[간 떨어지는 동거]\n보다가 너무 재미없어 안본다',
#  '[간택 - 여인들의 전쟁]\n이런거 환장하는 나는 너무 재밌다',
#  '[간택 - 여인들의 전쟁]\n사극?',
#  '[개와 늑대의 시간]\n이건 진짜 최고야 아너무재밌어',
#  '[개와 늑대의 시간]\n재미있어요.',
#  '[갯마을 차차차]\n자극적이지.않아 좋다',
#  '[갯마을 차차차]\n에필로그가 제일 재밌음 음악도 좋고 중간에 뭘했든(사건들이 좀 식상하긴하다) 끝날때는 기분 좋아진다',
#  '[갯마을 차차차]\n두 사람 미소만으로 청량한 바닷 바람 맞는 기분, 캐스팅 조합 미쳐따',
#  '[갯마을 차차차]\n청량한 바람이 불어오는듯 보는 내내 따스했다',
#  '[갯마을 차차차]\n잔잔하니 좋았다',
#  '[거침없이 하이킥]\n지금 봐도 재밌다 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '[거침없이 하이킥]\n또보고싶다',
#  '[거침없이 하이킥]\n아직도 재밌다, 미친거지',
#  '[거침없이 하이킥]\n디시 쇼츠로 봐도 재밌음',
#  '[거침없이 하이킥]\n나한테는 이게 전원일기라고',
#  '[검법남녀 2]\n그냥 그렇다.',
#  '[검법남녀 2]\n흥미진진',
#  '[겨울연가]\n볼만했음',
#  '[겨울연가]\n그 시절엔 좋았다',
#  '[겨울연가]\n맞는색깔을 입었을때',
#  '[경우의 수]\n돌고 돌고 또 돌고.',
#  '[경우의 수]\n확률이 낮아',
#  '[경우의 수]\n초반부는 그래도 좋았다',
#  '[경찰수업]\n이걸 내가 왜봤지..',
#  '[경찰수업]\n나름 매력적인 진부함과 유치함, 딱 거기까지',
#  '[계룡선녀전]\n옳지 착하다',
#  '[계룡선녀전]\n사랑스러운 작화, 사랑스러운 시선.',
#  '[계룡선녀전]\n뭉글뭉글해',
#  '[계룡선녀전]\n헐이거재밌았던듯!!!!',
#  '[계룡선녀전]\n귀엽고 따뜻해 사랑스럽고 감동적이야',
#  '[고교처세왕]\n개연성 하나도 없는데 재밌어',
#  '[고교처세왕]\n이거 진짜 재밌는데 볼사람',
#  '[고교처세왕]\n그냥 웃기고 재밌고,, 웃으면서 편하게 스트레스 풀려서 본 기억',
#  '[고교처세왕]\n이렇게 말이 안 되는데 재밌다니,,,',
#  '[고교처세왕]\n이👏🏻하👏🏻나👏🏻',
#  '[공작도시]\n마인이랑 비슷한 느낌',
#  '[공항 가는 길]\n서로에게 위안이 되어준 두 사람. 이 가을 그들을 보며 나도 위로 받았다.',
#  '[공항 가는 길]\n음악 풍경 분위기👍',
#  '[구경이]\n새로워!!! 짜릿해!!!',
#  '[구경이]\n진짜 개재밌음',
#  '[구미호뎐]\n그래, 내겐 한국 설화가 필요했어!',
#  '[구미호뎐]\n♥︎',
#  '[구미호뎐]\n유치하고 cg도 어색한데 은근히 또 가볍게 재밌음',
#  '[구미호뎐]\n보게된다..',
#  '[군검사 도베르만]\n무법변호사 작가래서 많은 게 납득 됨',
#  '[군검사 도베르만]\n스토리는 꽤 흥미있다.. 이야기 진행도 나쁘지 않게 짜놓았다..',
#  '[군검사 도베르만]\n작가가 뭐 어떻길래 하고 봤더니 아 그렇구나 싶다.',
#  '[군검사 도베르만]\n씹는 재미가 있다',
#  '[군검사 도베르만]\n현실감 있는 이야기. 현실감 없는 움직임.',
#  '[굿캐스팅]\n아씨 깜짝이야. 괜히봤다.',
#  '[굿캐스팅]\n유치하고 (아주 많이) 촌스럽지만 불편하지 않다. 스트레스 받지 않고 생각 없이 볼 수 있어 좋았다. 소소한 즐거움.',
#  '[굿캐스팅]\n뻔하지만 그래도 작품에 의의를. 전체적인 톤은 유쾌하지만 결코 가볍지는 않은.',
#  '[굿캐스팅]\n여성첩보원이라는 소재로 사람들에게 흥미를 끌어 올렸다. 그래서 나 역시도 봤다.',
#  '[궁]\nost는 지금 들어도 설렌다.',
#  '[궁]\n완전 만화같은 이야긴데 비웃음이 나온 적이 읎다. 로맨스에 설레느라.',
#  '[궁]\n그때는 유치해도 재밌게 봤었지 ㅋㅋㅋ',
#  '[궁]\n사랑인가요~~',
#  '[궁]\n나라꼴잘돌아간다',
#  '[그 겨울, 바람이 분다]\n흥미가 계속되지않는다.',
#  '[그 해 우리는]\n보고 있으면 이 모든 게 나와 우리의 얘기 같아서 우리도 그렇게 어려운 사랑을 하며 여기까지 왔구나, 너 없이 살 수 있다고 생각했던 건 나의 오만이었구나 하고 옆에 있는 사람이 더욱 소중하게 여겨지는 그 해 우리의 사랑 이야기.',
#  '[그 해 우리는]\n근래 보기 드문 깊은 이야기.',
#  '[그 해 우리는]\n청량감 넘치는 드라마가 시작되었다',
#  '[그 해 우리는]\n진짜 뻔한데 진짜 재밌어 그때 나를 보는 것만 같아서 그때 너를 보는 것만 같아서',
#  '[그 해 우리는]\n분위기는 아련하고, 포근하다. 이야기는 재치있고, 단단하다.',
#  "[그냥 사랑하는 사이]\n하루하루 숨 쉬는 것조차 힘든 현실 속에서 같은 아픔을 간직한 '사람'을 만난다는 자체만으로도 위로가 되며, 하물며 그 '사람'이 보내주는 '사랑'이야말로 가장 큰 위로가 되지 않을까.",
#  '[그냥 사랑하는 사이]\n그냥 잔잔해서 좋다.',
#  '[그냥 사랑하는 사이]\n오랜만에 내 취향. 진짜 좋다. 다 좋다.',
#  '[그냥 사랑하는 사이]\n묵직함의 연속.',
#  '[그냥 사랑하는 사이]\n있는 힘껏 행복해라!',
#  '[그냥 사랑하는 사이]\n과거의 손아귀에서 벗어나 성큼성큼.',
#  '[그냥 사랑하는 사이]\n진정으로 기억하기, 그리고 있는 힘껏 행복하기.',
#  '[그냥 사랑하는 사이]\n마음껏 애도하고 힘껏 행복해지기',
#  '[그놈이 그놈이다]\n무서워 근데 이야기가 이상해...',
#  '[그래서 나는 안티팬과 결혼했다]\n킬링타임용으로 재미있어요 귀엽고',
#  '[그래서 나는 안티팬과 결혼했다]\n귀...귀엽네요.',
#  '[그래서 나는 안티팬과 결혼했다]\n재미가 없다',
#  '[그래서 나는 안티팬과 결혼했다]\n찬열이 얼굴 감상했다.',
#  '[그리드]\n나만 이해를 못하는건 아니겠쥬? ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '[기름진 멜로]\n기대를 항상 벗어나는 그 지점이 신선',
#  '[김비서가 왜 그럴까]\n잔잔한 로맨틱 코메디 드라마',
#  '[꽃보다 남자]\nㅋㅋㅋㅋㅋㅋㅋㅋㅋ웃긴 영화',
#  '[꽃보다 남자]\n아라시 좋아했어서 2점준다..',
#  '[꽃보다 남자]\n재밌닼ㅋ',
#  '[꽃보다 남자]\n아니 나만 재밌어?',
#  '[나 홀로 그대]\n"만나고있잖아  밖에서~ 사람."',
#  '[나 홀로 그대]\n시즌 또 나와주세여',
#  '[나 홀로 그대]\n스토리와 상상력은 좋았다.',
#  '[나 홀로 그대]\n마음을 비우면 나름 킬링 타임용으로 볼만하다..',
#  '[나 홀로 그대]\n살짝 지루할 뻔 했다...',
#  '[나를 사랑한 스파이]\n잘 섞인 칵테일. An apt mix of action, absurdity, and affection.',
#  '[나를 사랑한 스파이]\n중간중간 갑자기 장르 코미디로 바뀌는게 너무 웃겨',
#  '[나를 사랑한 스파이]\n시리즈가 다시 좋아지려고 한다',
#  '[나를 사랑한 스파이]\n재밌어요',
#  '[나빌레라]\n◆ 할아버지의 몸을 느끼며',
#  '[나빌레라]\n뭘 할 때 가장 행복해?',
#  '[나의 나라]\n재밌자너 레알루ㅎㅎㅎ',
#  '[나의 나라]\n죽지도 않고 또오는..',
#  '[나의 나라]\n그래봤자 우렁이지.',
#  '[나의 아저씨]\n“죽고싶은 와중에 ‘죽지마라’, ‘당신은 괜찮은 사람이다‘, ’화이팅해라‘, 그렇게 응원해주는 사람이 있다는 것만으로 숨이 쉬어져.“',
#  '[나의 아저씨]\n좋은 어른이 되고 싶게 만드네',
#  '[나의 아저씨]\n괜찮은 사람, 좋은 사람이 곁에 있다는 것. 그게 내 편이라는데에서 이르는 편안함.',
#  '[나의 아저씨]\n나와 같은 처지에 있는 사람을 위로하며 내자신을 어루만지는 과정.',
#  '[나의 아저씨]\n착하다. 행복하자. 파이팅. 편안함에 이르렀나.',
#  '[나의 아저씨]\n괜찮은 드라마예요, 엄청. 좋은 드라마예요, 엄청.',
#  '[나의 해방일지]\n난 좋아 이런 드라마. 엄청나게 힘든 일도 아니고 그래서 누구에게도 딱히 못 말할거같은 그런 이상한 부분을 긁어주는 맛이 있다. 드라마가 내 마음을 읽어 줬다.',
#  '[나의 해방일지]\n누군가에게 해방과 추앙은 다소 작위적으로 느껴지겠지만, 누군가에게는 위로가 되는 말.',
#  '[나의 해방일지]\n왜 사냐고 물으면 그저 웃지요',
#  '[나의 해방일지]\n세상에 맞춰 걸어야 한다는 불안, 사람에 맞춰 변해야 한다는 강박, 머릿속 계산기와 마음의 짐을 내려놓으며, 비로소 조금이나마 트이는 삶의 숨통. 어쩌면 달라진 건 별로 없음에도, 이토록 꽉 닫힌 해피엔딩이라니! (2022.05.30.)',
#  '[나의 해방일지]\n완숙된 미완. 관계로써, 삶으로써, 존재로써.',
#  '[날 녹여주오]\n응? 😱',
#  '[날 녹여주오]\n할말없음',
#  '[날 녹여주오]\n제발 날 좀 만족시켜주오(라는 말이 계속 맴도네)',
#  '[날 녹여주오]\n내용이 아쉽긴 했지만.. 재밌었어요!',
#  '[날 녹여주오]\n재미없어',
#  '[날씨가 좋으면 찾아가겠어요]\n잔잔함이라는 컨셉 속 모두 내가 제일 괴롭다고 소리쳐대는 캐릭터들 때문에 보는 내내 너무 답답했다.',
#  '[날씨가 좋으면 찾아가겠어요]\n너무 잔잔해서 지루한 것 같다가도 또 그 분위기가 좋아서 계속 보게 되는 매력이 있다.',
#  '[날씨가 좋으면 찾아가겠어요]\n어두웠고 어두웠다. 춥고도 추웠고. 그걸 이겨낸 건 기분이 좀 나아지는 일을 해보잔 너의 말이었다.',
#  '[날씨가 좋으면 찾아가겠어요]\n날씨가 좋아지도록 찾아가겠어요.',
#  '[날씨가 좋으면 찾아가겠어요]\n너무 잔잔한 나머지 마지막까지 집중은 힘들 것 같다. 영화 한 편 정도의 호흡이었으면 어땠을까',
#  '[남자친구]\n요즘 내 존재에 이유',
#  '[남자친구]\n동화가 필요했고 동화가 있었다.',
#  '[남자친구]\n모두 각자의 자리에서 서로를 이해하려고 노력한다. 다만 시간이 필요할 뿐. + 섬세하고 상냥한 연출에 마음이 따뜻해지는 느낌.',
#  '[낭만닥터 김사부 2]\n울렸다가 웃겼다가..😂',
#  '[낭만닥터 김사부 2]\n밥 먹으며, 설거지 하며, 청소하며 잘 봤다. 시즌1보다는 보기 좀 편했다.',
#  '[낭만닥터 김사부 2]\n모든 사람을 낭만화.',
#  '[낭만닥터 김사부 2]\n가끔 좀 오글거려도 뭐 어떤가 싶고. 제목에 어울리게 낭만적임.',
#  '[내 뒤에 테리우스]\n소소한 재미가 많아서 보고있는데 일부러 페러디를 작정하고 연출한건가? ㅎㅎ',
#  '[내 뒤에 테리우스]\n내가 이상한가? 왜 재미가 없는지? 희안하도다~ 201811',
#  '[내 뒤에 테리우스]\n은근 재밌음',
#  '[내 아이디는 강남미인]\n은우야 재밌다',
#  '[내 아이디는 강남미인]\n첫 화 오프닝이랄까 발단이랄까, 절절하다.',
#  '[내 아이디는 강남미인]\n계속 보게 되기는 한데 불편함,, 비판하겠다고는 하는데 묘하게 전시해놓고 즐기는 느낌이라 그런가?',
#  '[내게 거짓말을 해봐]\n오에스티가 좋다',
#  '[내게 거짓말을 해봐]\n재미있음. 남주가 좀 답답하긴함',
#  '[내일]\n결국 만났네',
#  '[내일 그대와]\n머리비우고 즐기며 보는 동안 행복했다',
#  '[내일 그대와]\n소재는 익숙하나 사이에들어가는 스토리는 평범하면서 평범하지않다 그래서 더보는거같다',
#  '[내일 그대와]\n분위기가 정말 예쁘다..... 분위기 소재 연기 연출..... 다 너무나 맘에 든다',
#  '[내일 그대와]\n오늘.',
#  '[내일 그대와]\n무슨 정신으로 다봤는지 기억이...^^',
#  '[내일 그대와]\n잘생겼당~',
#  '[내일도 칸타빌레]\n심하다',
#  '[너는 나의 봄]\n보는 동안 따뜻했고 위로 받았고 그걸로 충분했다',
#  '[너는 나의 봄]\n가벼워보였는데.. 묵직하다. 잔잔한 위로같다가..미스테리하게 흐르다.. 마음이 생각에 잠기는 드라마..',
#  '[너는 나의 봄]\n떨고 있는 그날의 당신을 안아주지는 못했지만 그 시간을 이겨낸 지금의 당신을 안아주고 싶다는, 아마 가장 따듯한 위로',
#  '[너는 나의 봄]\na little 유치하고 당황스러움',
#  '[너는 나의 봄]\n위로받는듯한 드라마',
#  '[너는 나의 봄]\n한 권의 책 같았던 드라마. 담담하고 잔잔한 수평선을 보는 것처럼 차분하고 따듯해진다.',
#  '[너는 나의 봄]\n스릴러같기도 로맨스같기도 힐링같기도',
#  '[너는 나의 봄]\n불친절하지만 새롭다',
#  '[너는 나의 봄]\n따뜻하고 좋은데',
#  '[너도 인간이니]\n댓글이 웃겨서 +0.5',
#  '[너도 인간이니]\n시도는 좋았다. 용감했다.',
#  '[너를 닮은 사람]\n분위기 취향저격',
#  '[너를 닮은 사람]\n이런 느린 흐름의 드라마도 필요하다. 용서에 대해 생각해 볼 수 있는 시간.',
#  '[너와 나의 경찰수업]\n생각보다 재밌다 빨리 다음주 수요일이 왔으면 좋겠다',
#  '[너와 나의 경찰수업]\n생각보다 청춘물이라 재미가 쏠쏠하군',
#  '[너와 나의 경찰수업]\n잼나게 보고 있음',
#  '[너와 나의 경찰수업]\n재밌어요 이런 가볍고 간질간질 설렘도 살짝 있는 드라마 오랜만',
#  '[너와 나의 경찰수업]\n보고 있으면 저절로 미소가 지어지는. 오랜만에 기분좋게 볼 수 있는 드라마가 있어 좋아요. 서툴지만 반짝 반짝 빛나는 청춘들의 이야기가 잔잔하게 행복을 주는 드라마네요.',
#  '[너와 나의 경찰수업]\n살랑살랑 기분좋게 볼수 있는 드라마',
#  '[너와 나의 경찰수업]\n재미있고 설레고 멋짐이 다 있는 드라마',
#  '[너의 밤이 되어줄게]\n가볍게 시작했다가 이게 왜… 재미있지? 하면서 보게 됨',
#  '[닥터 진]\n뭔가 부족하지만 치료해 줄 때마다 기분 좋았다.',
#  '[닥터 프리즈너]\n이게 뭔가 싶을 정도의 씁쓸함만 남는다.',
#  '[단, 하나의 사랑]\n보는 맛이 있는걸 어떡해 ㅎ',
#  '[달리와 감자탕]\n달감과 함께한 가을… 행복했다…',
#  '[달리와 감자탕]\n귀엽고 소소하게 재밌음',
#  '[달리와 감자탕]\n귀엽고 유쾌한 드라마',
#  '[달리와 감자탕]\n제목이 이래서 그렇지 볼만했음다',
#  '[달의 연인 - 보보경심 려]\n난 좋다. 특히 강하늘 심쿵.',
#  '[당신이 잠든 사이에]\n너의 삼재가 보여.',
#  '[당신이 잠든 사이에]\n내 맘에 쏙',
#  '[당신이 잠든 사이에]\n전개 나쁘지 않은데',
#  '[대박]\n문제없이 잘 만들었다는 생각이 보는 내내 들었다.',
#  '[대박]\nunexpectedly very fun!!',
#  '[대박]\n후반으로 갈 수록 몰입되면서 더 재밌어진다',
#  '[대박]\n오 은근히 재미있어',
#  '[대박]\n앵간했음. 킬링타임용 드라마 느낌',
#  '[더 케이투]\n에잇 재미음썽',
#  '[더 케이투]\n넘넘 좋아요',
#  '[더 킹 : 영원의 군주]\n노잼',
#  '[더킹 투하츠]\n그냥 재밌게 봄',
#  '[도도솔솔라라솔]\n기분이 반짝, 마음이 따뜻. 만화같은 연출, 사랑스러운 캐릭터들. 앞으로 풀어 갈 이야기가 궁금하다.',
#  '[도도솔솔라라솔]\n아 진짜 결말 어이 없어서 웃음만 나오네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '[도도솔솔라라솔]\n유치한데 귀엽다 ㅋㅋㅋㅋ 둘의케미도 좋앗고',
#  '[도도솔솔라라솔]\n귀엽긴 함... 그냥 틀어놓고 딴짓하면서 보면 재밌음 ㅎㅎ',
#  '[도도솔솔라라솔]\n음.',
#  '[도도솔솔라라솔]\n대충 만든 느낌.',
#  '[도도솔솔라라솔]\n마을 분위기가 너무 좋다. 약간의 힐링.',
#  '[도시남녀의 사랑법]\n나는 무섭다, 안 된다, 부끄럽다, 망설인다, 주저한다, 고민한다 이런 생각들은 이제 안 하기로 결심했어 하나씩 하나씩 내 사전에서 지워가고 있는 중이야',
#  "[도시남녀의 사랑법]\n나'답고', '답지 않고'를 생각하지 말기 내 모든 모습이 전부 나라는 걸 받아들이기 무섭다, 망설인다, 부끄럽다, 고민한다 내가 느끼는 모든 감정이 전부 나라는 걸 받아들이기 사랑은 상대방의 모든 모습을 받아들이는 것",
#  '[도시남녀의 사랑법]\n사람이 거울에 보이는 것보다 가까이 있음.',
#  '[도시남녀의 사랑법]\n표현방식이 퍽 좋다',
#  '[독고 리와인드]\n와 시작한지 1분도 안됐는데 벌써 시간 아까워',
#  '[독고 리와인드]\n유치한 맛이지만 개재밌음',
#  '[독고 리와인드]\n과제물인가.',
#  '[독고 리와인드]\n유치한데 그게 장점인 작품',
#  '[돈꽃]\n아빠엄마가 보시기 시작하심.ㅋㅋ',
#  '[돈꽃]\n필주 웃는거 좀 보자!!!!! 너무하다 너무해',
#  '[돈꽃]\n보다보니 재밌다.',
#  '[돈꽃]\n뭔가 있을 뻔 하다 맘.',
#  '[동백꽃 필 무렵]\n행복은 쫓는게 아니라 음미하는거다',
#  "[동이]\n이야기보다는 '한효주' 의 매력을 느낄 수 있었던.",
#  '[동이]\n내친구 이름이랑 비슷해서 제목이 기억에 남음.',
#  '[동이]\n몰입이 안됨.',
#  '[드라마의 제왕]\n나만 재밌었나...',
#  '[드라마의 제왕]\n최시원은 이때부터 웃기기 시작했다 ㅋㅋㅋ',
#  '[드라마의 제왕]\n안 돼! 몰입하지마... 부러워하지마~',
#  '[드라마의 제왕]\n후반부로 갈수록 몰입도가 떨어졌고..(이하 생략)',
#  '[드라마의 제왕]\n볼만했어',
#  '[드림]\n마음에 깃든다. 음악들이, 배우들이.',
#  '[드림]\n노래는 좋았는데..',
#  '[따뜻한 말 한마디]\n시선의 차이. 진심 전달의 중요성.',
#  '[따뜻한 말 한마디]\n현실적이다',
#  '[따뜻한 말 한마디]\n내가참여한작품!',
#  '[땐뽀걸즈]\n무엇이든 과정과 결실, 그 안에서의 관계가 주는 기쁨은 참 좋다. 노력할수록 더더욱. 그걸 느껴본 지가 참 오래된 것 같다. / 친숙한 풍경 속 몰랐던 이야기 / 학생들의 에너지가 대단하다 ㅎㅎ - CGV 통영 1520 6E5',
#  '[땐뽀걸즈]\n어, 개이득.',
#  '[또! 오해영]\n별일 아니라는 말보다 괜찮을 거란 말보다 나랑 똑같은 상처를 가진 사람이 있다는 게 백배 천배 위로가 된다.',
#  '[또! 오해영]\n왠지인생드라마가될느낌적인느낌',
#  '[라디오 로맨스]\n윤두준 덕분에 행복했다.',
#  '[라디오 로맨스]\n대놓고 오글거리는 장면들이 있지만 그 오글거림이 재밌는, 기분 좋은 드라마!',
#  '[라디오 로맨스]\n비주얼이 개연성',
#  '[라디오 로맨스]\n이런 구시대적인 스토리라니!',
#  '[라이브]\n하 진짜 살아있네! 간만에 물건 만난 느낌!',
#  '[라이브]\n그들의 제복이 다시 보인다.',
#  '[라이브]\n회가 거듭될수록 사람냄새는 진해지며 제목  참 잘지었구나 싶다😀',
#  '[라이프 온 마스]\n당신이 행복한 그 곳이 현실입니다.',
#  '[라이프 온 마스]\n가끔 드라마나 영화 속 주인공들이 오래 오래 웃으며 행복하길 바라게 될 때가 있다. 이 드라마가 그랬다.',
#  '[라켓소년단]\n오글거리는데도 너무 좋다. 향기로웠던 민턴의 추억과 함께.',
#  '[라켓소년단]\n충격적이다........ 재밌어서...',
#  '[라켓소년단]\n귀엽고 무해해',
#  '[라켓소년단]\n무해하고 넘 재밌고 디테일도 넘 좋고 넘 귀엽다 흑흑',
#  '[라켓소년단]\n찌든 일상의 정화',
#  '[라켓소년단]\n선하고 유쾌한 파스텔톤 기운이 전해져 나이브해도, 재미 없어도(?) 보게 된다.',
#  '[란제리 소녀시대]\n사랑스럽다.',
#  '[란제리 소녀시대]\n난 넘좋은데 사투리도 귀여웠음',
#  '[란제리 소녀시대]\n화면이 참 이쁘고 음악도 좋다. 달달하고 아릿하고',
#  '[란제리 소녀시대]\n억수로 공감되네',
#  '[란제리 소녀시대]\n여성들의 용감함이 좋다',
#  '[란제리 소녀시대]\n재밌네',
#  '[런온]\n주인공들 할 말 다하고 약간 또라이같아서 재밌음',
#  '[런온]\n참 깨발랄해서 좋다.',
#  '[런온]\n첫느낌, 맘에 든다. 대사에 말맛이 느껴져서 좋다. 캐릭들도 똘끼가 느껴지는 게 좋아좋아.',
#  '[런온]\n내 취향 드라마 찾음',
#  '[런온]\nA-가 되고싶은 B+느낌..?',
#  '[런온]\n서로의 결핍을 채워주는 따뜻한 사람들. "섬세하고 다정한 사람들이 잘 살았으면 좋겠어. 상냥한 사람들을 바보 취급 안 했으면 좋겠어." / "우리는 아마 서로를 평생 이해 못 하겠죠?" "서로 다른 사람이니까." "저 사람은 저렇구나, 나는 이렇구나. 서로 다른 세계를 나란히 둬도 되지 않을까? 그러니까 우리 서로를 이해 못해도 너무 서운해하지 맙시다. 그건 불가해한 일이고 우리는 우리여서 할 수 있는 것들을 해내면 되지."',
#  '[런온]\n대사 하나하나 봤을 땐 재밌는데',
#  '[런온]\nBGM이 너무 좋다',
#  '[레버리지:사기조작단]\n쫄깃하면서도 코믹함으로 양념을 더했다',
#  '[레버리지:사기조작단]\n어..? 생각보다 괜찮은데...?',
#  '[레버리지:사기조작단]\n기대보단 괜찮은데?',
#  '[레버리지:사기조작단]\n유치하고 뻔한데 그럭저럭 볼만함',
#  '[로망스]\n미쳤네 이거',
#  '[로망스]\n안 좋게 특이하다.',
#  "[로맨스는 별책부록]\n'책'과 함께 '일하는 사람들'의 '다정다감함'.",
#  '[로맨스는 별책부록]\n주부의마음을 설레게하는구려😚',
#  '[로봇이 아니야]\n생각보다 재밌다! 귀여워',
#  '[루갈]\n노잼',
#  '[루갈]\n하지만 웃었죠?',
#  '[루갈]\n어처구니가 없지만 그래도 웃었으니까',
#  '[루갈]\n오랜만에 가족영화보니 유쾌하고 좋았음. 중세 배경이라 더 좋음.',
#  '[마녀식당으로 오세요]\n후루룩 가볍게 보기 좋다.',
#  '[마녀식당으로 오세요]\n기대보다 재밌다 나름 탄탄한 줄거리',
#  '[마녀식당으로 오세요]\n쉽고 재밌다. 교훈적인 메시지를 뻔하지 않고, 따뜻하게 전달하는 스토리텔링이 인상적이었다.',
#  '[마녀식당으로 오세요]\n모두 나와 닮아있는 식당의 손님들.',
#  '[마녀식당으로 오세요]\n너무 재밌어요. 감질맛 나네요. ㅜㅜ',
#  '[마우스]\n뻔할 뻔했는데 다행스러운 결론',
#  '[마우스]\n내가 좋아하는소재 재밌게 봤다.',
#  '[마이 걸]\n여주인공이 너무 예쁘게 성장해서 기뻤다. 그리고 잘 자라나고 있어서 대견하고 좋았음.',
#  '[마이 걸]\n1편과는 다른 따뜻함',
#  '[마이 네임]\n뭔가 계속 예상가능한 전개와 그 끝이 보이는..',
#  '[마이 네임]\n책 읽는 듯한 대사 특유의 초현실적 서정',
#  '[마이 네임]\n뻔하지만, 액션은 성공.',
#  '[마이 시크릿 호텔]\n재밌을 줄...',
#  '[마이 시크릿 호텔]\n서로 자기들 로맨스에 푹 절어버렸다',
#  '[마이 프린세스]\n.',
#  '[마인]\nYou can choose.',
#  '[맨도롱 또똣]\n....^^',
#  '[맨도롱 또똣]\n재미없어요',
#  '[맨도롱 또똣]\n보면서 행복했다',
#  '[맨투맨]\n웃기다 잼있다 ㅋㅋ 은근 시간잘가고 괜찮은거같다',
#  '[맨투맨]\n박해진 얼굴이 재밌다',
#  '[맨투맨]\n이거 코미디 맞죠?',
#  '[맨투맨]\n유치함 좀많이',
#  '[맨투맨]\n조잡하다',
#  '[맨투맨]\n재밌는소재. 프로페셔녈 멋졌다',
#  '[맨홀-이상한 나라의 필]\n내겐 재미는 있었던 드라마',
#  '[멀리서 보면 푸른 봄]\n미흡하고 안일하다.',
#  '[멈추고 싶은 순간: 어바웃 타임]\n나름 괜찮은 스토리가 맘에 들었다.',
#  '[멈추고 싶은 순간: 어바웃 타임]\n너무재미없다',
#  '[멈추고 싶은 순간: 어바웃 타임]\n신선한건 소재뿐이란 느낌',
#  '[멈추고 싶은 순간: 어바웃 타임]\n이해안돼...',
#  '[멜랑꼴리아]\n으으',
#  '[모단걸]\n짧아서 아쉬운데 짧아서 다행이다 싶기도 함',
#  '[모단걸]\n속았음',
#  '[모래시계]\n이때는 나쁘지 않았지 ㅋ',
#  '[모래시계]\n가슴 뭉클',
#  '[모래시계]\n미쳤다',
#  '[모래시계]\n깊다.',
#  '[모범형사]\n유쾌한 수미상관, 대단하진 않아도 안정적인 연기, 적절하게 섞인 유머와 스릴러의 조화,',
#  '[모범형사]\n공식화된 장면들이 쏟아져나오다보니 집중이 잘 안된다',
#  '[몬스터]\n좋은영화!',
#  '[몬스터]\n꿀잼',
#  '[몬스터]\n좋았던 기억.',
#  '[몬스터]\n노래 하나 믿고',
#  '[몬스터]\n음악 달빛 웃음.',
#  '[몬스터]\n노래만 좋음',
#  '[몬스터]\n다소 평범하지만, 유머러스한 묘사가 나쁘지 않은 애니메이션',
#  '[무법 변호사]\n재밌어요.',
#  '[무법 변호사]\n복습복습복습',
#  '[무법 변호사]\n끝) 왜 봤지..',
#  '[무브 투 헤븐 : 나는 유품정리사입니다]\n마치 좋은 클래식 음반을... 시각을 통해, 감성을 통해 느껴본...',
#  '[무브 투 헤븐 : 나는 유품정리사입니다]\n신선함이 익숙함으로 변하는 매직',
#  '[미남이시네요]\n따뜻한데 뭔가 불편하다',
#  '[미남이시네요]\n원작 특유의 디테일은 잘 살렸으나 깊진 않고 낡았다. 현대 기준 불편한 유쾌함 투성이 작품.',
#  '[미남이시네요]\n소소한 일상을 보여주며 결국 교훈을 주는, <그렇게 일드는 위로가 된다>',
#  '[미남이시네요]\n아 개웃겨',
#  '[미남이시네요]\n깔끔하고 재미있고 다정하고❤️',
#  '[미남이시네요]\n일상에서 느낄수있는 감정들에 대한 개그적 교훈!! 최고',
#  '[미래의 선택]\n첨엔 좋았는데..',
#  '[미래의 선택]\n신선한것뿐',
#  '[미래의 선택]\n유치해서 하차했던거 같은데',
#  '[미스터 기간제]\n잼있음',
#  '[미스터 기간제]\n보고싶어여',
#  '[미스터 션샤인]\n저 또한 즐거운 소풍이였습니다.',
#  '[미스터 션샤인]\n낭만에 취한 줄 아는 자아도취',
#  '[미스티]\n물 속에 빨려들어가는 기분.',
#  '[미안하다 사랑한다]\n<지95락실-3> 보고 넘어온 사람들의 모임 🙌🏻',
#  '[바람의 화원]\n기억나는 게 많은 영상과 관계성이 좋았다',
#  '[바람이 분다]\n흥미가 계속되지않는다.',
#  '[발칙하게 고고]\n나도 저 들속으로  들어가서  미치고싶다',
#  '[발칙하게 고고]\n생생하고 신나는 사운드를 영화에서 만날수 있는 기쁨',
#  '[발칙하게 고고]\n우리에겐 놀 자유가 있습니다.',
#  '[밥 잘 사주는 예쁜 누나]\n해인이 보는 즐거움을 느끼는 정도',
#  '[밥 잘 사주는 예쁜 누나]\nTV에 빠져들어가는 줄 알았다.',
#  '[밥 잘 사주는 예쁜 누나]\n웰메이드인척하는',
#  '[밥 잘 사주는 예쁜 누나]\n초반의 설렘만 좋았다.',
#  '[백일의 낭군님]\n지금 나만 불편한가.',
#  '[백일의 낭군님]\n생각보다 재밌게 봤다',
#  '[백일의 낭군님]\n디오에빠졌다😘',
#  '[백일의 낭군님]\n재밌긴한데 오글거려 죽는줄 ㅎㅎ',
#  '[별똥별]\n가볍게 보기 좋았다. 큰 자극 없고 등장인물이 소소하게 귀여웠다.',
#  '[별똥별]\n가벼워서 존잼.',
#  '[별똥별]\n스토리를 떠나 배우들의 케미가 좋아서 괜히 기분 좋아지는 드라마',
#  '[별똥별]\n재밌는것 같아요',
#  '[별똥별]\n유치하지만 가볍게 보기는 딱 좋음',
#  '[별똥별]\n무거운것만 보다가 기분전환용으로 좋음',
#  '[별똥별]\n킬링타임용 힐링 로맨스물. 가볍고 달달하게 보기 좋음.',
#  '[별똥별]\n이거 재밌음',
#  '[별똥별]\n아주 가볍게 보기 좋은 힐링 드라마~ 간만에 웃으면서 보기 편했다요😌',
#  '[별똥별]\n넘넘 재미땨 남주 연기빼고',
#  '[별똥별]\n유치하고 몽글몽글하구.',
#  '[별에서 온 그대]\n그래도 재미있었어.',
#  '[별에서 온 그대]\n다시 봐도 설레는 작품',
#  '[별에서 온 그대]\n사랑입니다',
#  '[병원선]\n하아,,,내 시간',
#  '[병원선]\n첫회는 괜찮았다...',
#  '[병원선]\n아내의 유혹 챙겨봤던 사람들 기분을 조금은 알꺼같아',
#  '[보쌈-운명을 훔치다]\n기대 이상!',
#  '[보이스2]\n아오 스트레스받아',
#  '[보좌관]\n뭉클하다',
#  '[복수가 돌아왔다]\n스토리는 그저그런데 배우얼굴합이 레전드임 얼굴보는 재미에 너무재밌게 봤다',
#  '[복수가 돌아왔다]\n너무유치해근데너무재밌어',
#  '[복수가 돌아왔다]\n복수야.. 다시 돌아가',
#  '[복수가 돌아왔다]\n나만 재밌어? 나만 재밌냐구',
#  '[복수가 돌아왔다]\n여러모로 아무튼 웃김',
#  '[복수가 돌아왔다]\n얼굴이 다했다',
#  '[부부의 세계]\n잔뜩 힘 줘서 멋부리기',
#  '[부암동 복수자들]\n똑같은 처지라는 게 가장 마음에 든다.',
#  '[부암동 복수자들]\n현재까지 너무 재미있어 미치겠다 ㅠㅠ',
#  '[부암동 복수자들]\n매주 유쾌하고 통쾌하다. 현재 삶의 락.',
#  '[부암동 복수자들]\n유쾌상쾌통쾌',
#  '[부암동 복수자들]\n유쾌했다',
#  '[부암동 복수자들]\n뭔가 짜릿한 복수는 아니었지만 그녀들이 행복해져서 기분 좋다.',
#  '[부암동 복수자들]\n이런 유쾌, 상쾌, 통쾌한 드라마 같으니라그😄',
#  '[부암동 복수자들]\n코메디라면 이런것이 좋다.',
#  '[불가살]\n현생을 좀 살아라...-_-',
#  '[붉은 단심]\n재밌다가 길을 잃는다.',
#  '[뷰티 인사이드]\n아주 간단한 수식이 아주 더디게 풀리는 과정을 지켜보는 기분',
#  '[뷰티 인사이드]\n언행불일치.',
#  '[뷰티 인사이드]\nn번의 얼굴과 n개의 표정을 통해 신기할정도로 세밀하게 드러나는 온갖가지 감정의 결. 일단 재미가 있었습니다.',
#  '[빅마우스]\n보는 중',
#  '[빈센조]\n하차...',
#  '[빈센조]\n개연성은 개나 줬지만 통쾌하다.',
#  '[빈센조]\n하나도 안 웃긴데 너네끼린 재밌었을까?',
#  '[빠담빠담…. 그와 그녀의 심장박동소리]\n드문드문 보이는 오글거림만 잘 견뎌내면 재밌다.',
#  '[빠담빠담…. 그와 그녀의 심장박동소리]\n아 좀 지루하긴 했는데 그 잔잔한 분위기가 좋았다',
#  '[사내맞선]\n아는 맛이. 제일. 맛있다.....',
#  '[사내맞선]\n유치한데 뭔가 계속 보고 싶어...ㅎ',
#  '[사내맞선]\n진짜 유치한데 왜케 웃기냐 ㅋㅋ',
#  '[사내맞선]\n유치한게 제일 좋아',
#  '[사내맞선]\n나는 재미있게 잘 보고 있는데...ㅜㅜ (눈치)',
#  '[사내맞선]\n아주 코믹한 2000년대 드라마',
#  '[사내맞선]\n유치하고 뻔하지만 재밌었다.',
#  '[사내맞선]\n보고 있다는 걸 숨기고, 재밌게 봤다...',
#  '[사내맞선]\n나 이런게 좋아하네',
#  '[사랑비]\n유성영화가 존재함에 감사하게 느껴진다.',
#  '[사랑비]\n설레고 신나는거 high인 기획이에요.',
#  '[사랑비]\n아, 오디오에 섞인 잡음마저 좋다.',
#  '[사랑의 불시착]\n재밌기만 하구먼',
#  '[사랑의 불시착]\n유치한데 자존심 상하게 재밌어서 보는동안 실실 웃고있음',
#  '[사랑의 불시착]\n열심히 정주행중 캐미가 좋더니 .. 사귀는구나 ㅋ',
#  '[사랑의 온도]\n대사가 다른 로맨스 드라마와는 약간 다르다. 분위기도 너무 좋고 설렌다',
#  '[사랑의 온도]\n캐릭터들이 하나같이 다 담백해서 계속 웃음이 나온다 —',
#  '[사랑의 온도]\n서현진...너무좋다',
#  '[사랑의 온도]\n진짜 너무 재밌어요',
#  '[사생활]\n잡스럽다',
#  '[사이코지만 괜찮아]\n두 사람 다 안쓰러운데 멋있다. 엄마는 따뜻했다.',
#  '[사이코지만 괜찮아]\n상담을 전공했기에 더 흥미로웠다.',
#  '[사이코지만 괜찮아]\n행복해질 용기는 당신에게 있어요.',
#  '[사임당, 빛의 일기]\n오랜만에 보는 진부함에 신선함마저 느껴진다. >_<',
#  '[사임당, 빛의 일기]\n보보...경심...의 기운이 느껴진다...',
#  '[사임당, 빛의 일기]\n진부하게느껴지는 판타지다. 인내심을 가지고  봐야할듯',
#  '[사춘기 메들리]\n풋풋해서 귀엽고 설렜다',
#  '[사춘기 메들리]\n청량감 넘치는 ost, 싱그러운 풍경, 풋풋한 주인공들',
#  '[사춘기 메들리]\n나도 저런 설렘좀..',
#  '[사춘기 메들리]\n오랜만에 봐도 설레고 따뜻하다',
#  '[사춘기 메들리]\n재밌네',
#  '[사춘기 메들리]\n떠올리면 기분 좋아지는 드라마. ost가 신의 한수',
#  '[상속자들]\n욕하면서보는재미가 쏠쏠하다',
#  '[상속자들]\n꽃보다남자보단 덜 오글거림',
#  '[상속자들]\n올만에 다시봤는데도 참 재미지다.  20190717',
#  '[상속자들]\n영도가 다 했다.',
#  '[상속자들]\n영도야 잘지내니',
#  '[상속자들]\n"많이 먹어, 전학생" 나에게도 내 앞에서 나 구경하는 영도가 있었음 좋겠네.',
#  '[서른, 아홉]\n좋은 사람, 좋은 어른, 좋은 친구',
#  '[선배, 그 립스틱 바르지 마요]\n다른 일 하면서 켜놓기 좋았던 잔잔한 드라마.',
#  '[선배, 그 립스틱 바르지 마요]\n뭐 나름대로 잔잔하게 괜찮았다. 나는 원진아 괜찮더라.',
#  '[선배, 그 립스틱 바르지 마요]\n잔잔하고 평이한 플롯에서 캐릭터가 더 빛나기도 하는 법.',
#  '[선배, 그 립스틱 바르지 마요]\n나 이런게 좋아하네',
#  '[선배, 그 립스틱 바르지 마요]\n로운 얼굴이 정말 재밌다',
#  '[설강화]\n정신차려라',
#  '[세상 어디에도 없는 착한남자]\n그리고 난 다시 신에게 기도한다 고맙습니다 난 지금 행복합니다.',
#  '[세상에서 제일 예쁜 내 딸]\n역시나 엄마랑 같이 보면 재밌다',
#  '[소년심판]\n머리가 띵하다.',
#  '[소년심판]\n오랜만에 몰입했다',
#  '[소년심판]\n문제에 대한 균형 잡힌 시선',
#  '[쇼핑왕 루이]\n나름 케미 좋네 생각보다 더 좋네 덧. 리트리버가 생각난닼ㅋㅋ 누군지는 보면 알듯',
#  '[쇼핑왕 루이]\n스트레스 없이 힐링됨 루이야ㅑ',
#  '[쇼핑왕 루이]\n사랑스러워',
#  '[쇼핑왕 루이]\n보고있으면 절로 미소가 ㅋㅋ',
#  '[쇼핑왕 루이]\n한편의 그림책을 본듯한 느낌이다.',
#  '[쇼핑왕 루이]\n작가시선이 따스함',
#  '[쇼핑왕 루이]\n귀여워',
#  '[쇼핑왕 루이]\n그냥 좋다 나쁘다? 아니다 그냥 보기 편하다 그래서 좋다',
#  '[순정에 반하다]\n인소같은데 설레. 짜증나.',
#  '[순정에 반하다]\n뻔하고 유치한데 재밌다',
#  '[순정에 반하다]\n사랑이라는 감정의 풀 스펙트럼. 감동적이었다.',
#  '[슈츠]\n가볍게 볼만했다',
#  '[스물다섯 스물하나]\n현실에서 시달리다 희도의 순수함을 보고 있으면 괜히 기분 좋아진다. 나한테 힘내라고 하는 것 같다. 현실 속의 이진이 되어 드라마를 보는 느낌',
#  '[스물다섯 스물하나]\n서로가 서로에게 있어 힘이 되줄 때',
#  '[스위트홈]\nCG돈 좀 써줘요 ... 몰입도가 중요한데...',
#  '[스위트홈]\n기억이 있으면 감정도 배울수있다.',
#  '[스위트홈]\n작가님/감독님 혼자 감동하며 울지말고 저도 좀 낍시다...',
#  '[스위트홈]\n기대합니다.',
#  '[스위트홈]\n나는 너무너무 재밌게 봤다.',
#  '[스카이캐슬]\n공감되는것도 있구 재밌게 봤는데 ㅋㅋ 마지막에 뭐람 ㅋㅋㅋㅋ',
#  '[스카이캐슬]\n기빨려..',
#  '[스토브리그]\n달지 않고 맛있네요.',
#  '[스토브리그]\n숨겨진 이면을 탐색하는 박진감, 현장감.',
#  '[스토브리그]\n새로우면서 재미있기까지.',
#  '[슬기로운 감빵생활]\n‘감옥’이라는 생소한 공간을  유쾌하게 그려내었다.',
#  '[시간]\n마음이 흔들렸다. 여진이 길었다.',
#  '[시간]\n오랜만이다 이 느낌 이 맛에 영화를  보는게 아닐까',
#  '[시간]\n너무 재미있어서 보다가 "잼있다"를 육성으로 외침.',
#  '[시간]\n기다림이란 지난한 과정이니 때론 어려움도 있겠지만 이젠 처음처럼 소란하지는않게 통과해낼 수 있을거에요 그대가 뜯어낸 몇조각 여름햇살이 여전히 내 가슴에 따뜻하니까.. 꼭 그때까지만',
#  '[시그널]\n무전은 다시 시작될 겁니다.',
#  '[시지프스: the myth]\n꾸역꾸역 보고 있지만',
#  '[시지프스: the myth]\n끝까지 본 나 칭찬해',
#  '[시카고 타자기]\n유치한 재미가 있는데 반복되는 상황에 보다가 지치게 된다.',
#  '[시카고 타자기]\nOST가 좋고요, 노래가 진짜 좋고요, OST가 좋아요..',
#  '[시카고 타자기]\n덕질은 승리한다.',
#  '[시카고 타자기]\n여기 우리의 얘기를 쓰겠소',
#  '[시크릿 가든]\n귀엽고 시각적으로 즐거운 영화',
#  '[시크릿 가든]\n건강한 아이, 회복해가는 어른을 보는 것은 언제나 좋다. 자연의 아름다움을 보는 것이 즐거웠다.',
#  '[시크릿 가든]\n마음 한구석이 따뜻해지는 영화',
#  '[시티홀]\n궁금했다 서울신청사 난 그냥 나쁘진 않던데 쨌든 그래도 너무행',
#  '[시티홀]\nㄹㄹ',
#  '[식샤를 합시다 3]\n뭔가 다 어색하다',
#  '[신데렐라와 네 명의 기사]\n유치하고 좋구만? 얼마나 좋아. 넷 다 훈훈하고. 네 명이 다 소담이 좋아해버려라. 완전 유치하게 가자.',
#  '[신데렐라와 네 명의 기사]\n난 이게 왜재밌냐?',
#  '[신데렐라와 네 명의 기사]\n오글거리는데 보게 된다 재밌어서 자존심 상함',
#  '[신데렐라와 네 명의 기사]\n유치한 입맛에 저격',
#  '[신사와 아가씨]\n나만 재밌나 ..?',
#  '[신입사관 구해령]\n소재도 신선하고 좋았다',
#  '[싸이코패스 다이어리]\n재밌는데 답답',
#  '[싸이코패스 다이어리]\n보고싶다..',
#  '[싸이코패스 다이어리]\n괜찮은것 같음.',
#  '[쌈 마이웨이]\n걔가 날 우습게 본다고 내가 우스워 지나',
#  '[쌈 마이웨이]\n그들의 꿈을  응원하고  기뻐하는 청춘. 그게 나야 나! 좋았다.',
#  '[쌈 마이웨이]\n배우들의 캐릭터에 대한 이해도가 돋보이는 작품.',
#  '[쌈 마이웨이]\n유치한 부분도 유쾌하게 넘어갈 수 있다면, 배우도 연출도 각본도 잘 쓴 드라마라는 증거.',
#  '[쌈 마이웨이]\n이 사람들 덕분에 여름이 즐거웠다.',
#  '[쌍갑포차]\n웰메이드.',
#  '[쌍갑포차]\n에피소드 형식이라니 기대중',
#  '[아는 와이프]\n예상처럼 흘러가는 전개 방식 다 알 것만 같은 에피소드들',
#  '[아랑사또전]\n갠적으로 ost가 너무 좋아서',
#  '[아랑사또전]\n사극이 오글거리면 귀엽다.',
#  '[아랑사또전]\n나..이거 봤다',
#  '[아랑사또전]\n아... 괜히 봤다',
#  '[아름다운 그대에게]\n유치하다. 인정하고 싶지 않지만 재밌었다.',
#  '[아름다운 그대에게]\n오글거리는데 자꾸 보게된다 ㅋㅋㅋㅋㅋㅋ 하',
#  '[아름다운 그대에게]\n토마 귀엽넹',
#  '[아름다운 그대에게]\n내가 대단하다.',
#  '[아름다운 그대에게]\n솔직히 재밌었다 ㅇㅈ?ㅇㅇㅈ~',
#  '[아름다운 그대에게]\n옛날 재미있게 본 일드',
#  '[아름다운 그대에게]\n일본 특유의 개그감이 아주 귀엽게 베어 있어서 풋하고 웃음을 터트린 순간도 많았고 색채가 파스텔톤으로 이뻤다!',
#  '[아름다운 그대에게]\n내청춘 그리고 웃음 보따리',
#  '[아름다운 그대에게]\n유치하고 꿀잼',
#  '[아름다웠던 우리에게]\n이 집 남주 얼굴 잘하네.',
#  '[아름다웠던 우리에게]\n남자주인공 얼굴이 재밌다😆',
#  '[아버님 제가 모실게요]\n잼잇어요~^^',
#  '[아스달 연대기]\n기대됨 빌드업 했으니 포텐터지길',
#  '[아스달 연대기]\n또 선물처럼 돌아오길 희망해봅니다',
#  '[아스달 연대기]\n생각보다 괜찮아서 놀라운',
#  '[아스달 연대기]\n나라는 이야기로 만들어지는 거야',
#  '[아스달 연대기]\n재미있어요! 2023. 12. 11. ~ 2023. 12. 24.',
#  '[아스달 연대기]\n재밌기만한데....',
#  '[아이리스]\n.',
#  '[아이리스]\n이거 본 사람은 ㄹㅇ 나뿐일걸?^^ 꽤 재미졌어유~',
#  '[아이리스]\n^ㅗ^',
#  '[아이언맨]\n당신의 이야기 잘들었어요!',
#  '[아이템]\n약간 조금 마음이 따땃 든든해지는 모건 프리먼적 허용',
#  '[아이템]\n행복하다. 소소하게. 다신볼수없지만.',
#  '[아이템]\n현대인들에게 가장 필요한, 내 이야기를 맘껏 들어줄 사람. 소통해주는 사람.',
#  '[아이템]\n힐링무비',
#  '[아이템]\n아이가 사자에게 웃는법을 가르치는것',
#  '[아이템]\n불안감을 유대감으로 뒤바꾸는 매력적인 배우들의 집합.',
#  '[아이템]\n잔잔하면서도 가볍게, 그리고 살며시 미소 지을 수 있는 그런 작품. 러닝타임도 짧고 부담없이 기분전환할 수 있는 이야기.',
#  '[아이템]\n묘하게 지루하지도 않고 매력 있네.',
#  '[아이템]\n가슴 따뜻해지는 힐링영화',
#  '[아이템]\n마지막에 그가 한 고민에 공감한다.',
#  '[아이템]\n누군가의 일상을 엿본 기분. 근데 엿본 일상이 아주 특별한 하루다. 지친 사람들에게 담담히 추천',
#  '[아이템]\n유쾌하고 따뜻하다.. 행복한 10가지 생각해봐야지!',
#  '[아이템]\n걍 편안하게 볼만한데 소소하게 웃김ㅋㅋㅋㅋㅋ',
#  '[아이템]\n살아가면서 가끔은 쉼표 하나, 그리고 자신감 한 스푼',
#  '[아홉수 소년]\n아직도 너무 좋다.',
#  '[아홉수 소년]\n기대가 됩니다',
#  '[아홉수 소년]\n음악으로 모든걸 커버하기는 조금 벅찼다 정말, 진짜 아무 생각 없이 가볍게 보기에는...좋다',
#  '[아홉수 소년]\nost의 즐거움',
#  '[아홉수 소년]\n다 너무 좋았던.. 억지가 있어도 좋았던..',
#  '[아홉수 소년]\n재밌쩌요',
#  '[아홉수 소년]\n마치 포장지가 없는 다양한 이야기를 보는 기분이 들었던 드라마.',
#  '[악마가 너의 이름을 부를 때]\n오, 간만에 재밌는 드라마가 나올 것 같은 그런 느낌!!!👀 (제목, 스토리라인도 마음에 든다)',
#  '[악마가 너의 이름을 부를 때]\n좋은 노래, 좋은 배우, 다양한 감정',
#  '[악마가 너의 이름을 부를 때]\nost가 너무 좋다',
#  '[악마가 너의 이름을 부를 때]\n나레이션으로 설명하려는 드라마..',
#  '[악마판사]\n진짜 의리로 봤다..🥲 행복해 요한 앨리아,',
#  '[악의 마음을 읽는 자들]\n연기가 맛있다',
#  '[악의 마음을 읽는 자들]\n실화라 그런지 몰입도가 미쳐버림',
#  '[악의 마음을 읽는 자들]\n갈수록 오글오글…',
#  '[안투라지]\n답답한 느낌은 있지만…',
#  '[알고있지만]\n흐헿 상위포식자 어항에 들어가본 자, 이 드라마를 공감할 지어다',
#  '[알고있지만]\n묘하게 끌린단말야 ¯ࡇ¯',
#  '[알고있지만]\n자극적이지 않고, 미묘해서 좋았고 솔직해서 끌렸다.',
#  '[알함브라 궁전의 추억]\n이게 그렇게 신선함...?',
#  '[알함브라 궁전의 추억]\n제 기억도 리셋해주세요🤬',
#  '[앨리스]\n아~ 첫 화 느낌이 좋다 조만간 입소문이 날 것 이라고 자부 할 수 있음',
#  '[앨리스]\n이병헌의 손길이 닿은 것 같긴 한데.',
#  '[앨리스]\n청불하길 잘했다.',
#  '[앨리스]\n찾았다,, 무릎반사 같은 드라마 ❤️',
#  '[앨리스]\n신박하게 웃기네. 왓챠가 가끔씩 잘하네 ㅋ',
#  '[앨리스]\n저희들은 웃음을 참지 못하는 병이 있어요',
#  '[앨리스]\n케미는 좋은데',
#  '[앨리스]\n하하하하하하하하하하하하너무재밌다',
#  '[어게인 마이 라이프]\n갑자기 진행되서 끝난 기분이다ㅠ',
#  '[어게인 마이 라이프]\n아, 재미있었는데 분명히',
#  '[어게인 마이 라이프]\n괜찮음.',
#  '[어게인 마이 라이프]\n진부하지만 재밌다.',
#  '[어게인 마이 라이프]\n캐릭터나 내용전개가 유치하고 오글거리지만 계속 보게 되는 흡입력은 뛰어나다.',
#  '[어게인 마이 라이프]\n지나치게 얽히지 않고, 최대한 가볍게',
#  '[어게인 마이 라이프]\n긴 호흡으로 진행되어야할 이야기가 아닌가 싶다',
#  '[어느 날 우리 집 현관으로 멸망이 들어왔다]\n오...신선해..아...아니네..',
#  '[어느 날 우리 집 현관으로 멸망이 들어왔다]\n나는 재미있는데...',
#  '[어느날]\n몰입도는 좋았지만 마무리가...',
#  '[어느날]\n쓸데없이 길다..',
#  '[어느날]\n시간아깝다',
#  '[어바웃타임]\n신선한 로맨스인줄로 알았는데 이건 행복에 대한 이야기.  이 영화로 인해 더 행복해졌다',
#  '[어바웃타임]\n시사회 관람하고 온 사람입니다.',
#  '[어바웃타임]\n다시 나를 되돌아보며 전보다 더 아름다워질 시간여행을 위해서',
#  '[어쩌다 발견한 하루]\n아니 얼굴들이 겁나게 재미있네',
#  '[언더커버]\n묘하다',
#  '[여름 향기]\n여름의 향기가 느껴진다.',
#  '[여름 향기]\n노래 진짜 좋다',
#  '[여름향기]\n여름의 향기가 느껴진다.',
#  '[여름향기]\n노래 진짜 좋다',
#  '[여신강림]\n좀 오글거리긴하는데 취향 맞으면 꿀잼임',
#  '[여신강림]\n남녀주인공 얼굴 걍 존잼; 유치한데 설레💛',
#  '[여신강림]\n세상 유치하지만  참 따듯하고 사랑스러워',
#  '[여인의 향기]\n알파치노에 취한다',
#  '[역도요정 김복주]\n자극적인 이야기가 아니라 좋았다.',
#  '[역도요정 김복주]\n아프니까....? 어쨌든 청춘이라 부럽다',
#  '[역도요정 김복주]\n유치하지만 풋풋하다.',
#  '[역도요정 김복주]\n스웩',
#  '[역도요정 김복주]\n그냥 20대초반의 느낌이 싱그럽다 이런 청춘물좋다',
#  '[역도요정 김복주]\n비주얼 만큼은 인정',
#  '[역도요정 김복주]\n풋풋했다. 내가 대학생이 된 기분',
#  '[연애의 발견]\n상황자체는 억지스러울수도 있지망 대사 하나하나 들어보면 정말 내맘을 들여다봤나 싶을정도로 현실돋는 드라마',
#  '[연애의 발견]\n참 묘한 일이야.',
#  '[연애의 발견]\n그래 나 원래 이렇게 온몸이 저릿저릿한 사랑놀이 좋아했어. 으.여름냄새난다.좋다.',
#  '[열두밤]\n잔잔하다. 잔잔하게 생각이 밀려온다.',
#  '[열여덟의 순간]\n공감이 갈듯 말듯~ 짜증이 날듯 말듯~~',
#  '[열여덟의 순간]\n하 좀 설랬다',
#  '[열혈사제]\n시간은 흘렀는데 시즌 1에서 멈춰버린 이야기.',
#  '[열혈사제]\n이것이 뭐에요; 더 유치해졌잖아 . . . 액션은 좋아서 별하나 더',
#  '[열혈사제]\n개그를 못해서 안달이 났나? 한없이 가볍다.',
#  '[영광의 재인]\n와 난 이거 진짜 재밌게 봤다',
#  '[영광의 재인]\n옛날에 되게 재밌게 봄',
#  '[오 나의 귀신님]\n안 웃으며 보려고 해도 어느새 얼굴은 미소를 짓고 있다.',
#  '[오 마이 금비]\n애기때문에 본다 근데.뭔가 새론이 느낌',
#  '[오 마이 레이디]\n코믹하고 ㅋㅋ재밌게봄',
#  '[오! 주인님]\n둘이 어울려.',
#  '[오렌지 마말레이드]\n또 또 나만 재밌게 봤지..',
#  '[오렌지 마말레이드]\n연기와 스토리가 유치했다ㅜ',
#  '[오렌지 마말레이드]\n엄청 재미있어요',
#  '[오월의 청춘]\n역사가 스포인 드라마에서 이 정도면 운도 잘 띄웠고, 마무리도 잘 했다는 생각이 든다. 그 날에 대해서 여러 각도로 생각해보게 되었다.',
#  '[옥탑방 왕세자]\n유치하지만 귀여웠다',
#  '[옥탑방 왕세자]\n이거볼시간에 미드를 볼껄...',
#  '[옥탑방 왕세자]\n뻔한 매력에 흠뻑 빠졌던',
#  '[옥탑방 왕세자]\n어릴 때 재밌게 본 기억',
#  '[옥탑방 왕세자]\n유치뽕짝하지만 너무 신선했던 좋은 드라마',
#  '[옥탑방 왕세자]\n웃겼다. 비슷한 시기에 비슷한 소재의 드라마가 인기가 있었는데 그 중에 제일 허술하고 말도 안되는 부분이 많았지만 그 중에 제일 유쾌하고 재밌어서 인기 있었던게 아닌가 싶다.',
#  '[옷소매 붉은 끝동]\n마지막화가 특히 좋았음..',
#  '[옷소매 붉은 끝동]\n나 미치겠어요..',
#  '[옷소매 붉은 끝동]\n애절하기 그지없구나ㅠ 같이 웃고 울게 되네',
#  '[왕은 사랑한다]\n요즘 굉장히 잘보고있음. 대사 하나하나 너무애절함 이것은 너를 나보다 더 사랑해버린 나의 이야기다',
#  '[왕은 사랑한다]\n외모 상향, 연기 하향 평준화.',
#  '[왕은 사랑한다]\n작가반성해라',
#  '[왕은 사랑한다]\n예상했던 뻔함, 따로 노는 케미.',
#  '[왕은 사랑한다]\n아직까진 좋음.중간 광고빼면 더좋음',
#  '[왕이 된 남자]\n내 마음을_다림질 해주었다_ 축축하게_따뜻하게_반듯하게_',
#  "[왕이 된 남자]\n한국 휴먼코미디물이 갖고 있는 고질병 중 하나인 '억지'가 없으니 시종일관 흐뭇하다",
#  '[왕이 된 남자]\n사람냄새가 났기에 우리는 쉽게 다가서고 공감할 수 있었다.',
#  '[왜 오수재인가]\n뭘 얘기하고 싶은 지 모르겠는 전개',
#  '[우리, 사랑했을까]\n가벼운 마음으로 보기 좋다',
#  '[우리, 사랑했을까]\n우리, 사랑하고 있어',
#  '[우리, 사랑했을까]\n뒤로 갈수록 의리로 보는중',
#  '[우리, 사랑했을까]\n가볍게~가볍게~볼만~.. 22.8.25-8.28',
#  '[우리, 사랑했을까]\n주인공보다 다른 인물이 더 매력적이고 궁금하다',
#  '[우리, 사랑했을까]\n난해함',
#  '[우리는 오늘부터]\n배우들 웃참 찾는 거 재미있다. ㅋㅋㅋ',
#  '[우리는 오늘부터]\n배우들 웃참하는 모습 여실히 보여주는 게 관전 포인트',
#  '[우리는 오늘부터]\n바보라서 다행이다~',
#  '[우리는 오늘부터]\n이마이 산뜻한 미소 진짴ㅋㅋㅋㅋㅋ개웃겨ㅋㅋㅋㅋㅋ 2021.02.22',
#  '[우리는 오늘부터]\n행복하면 됐다 이마이...,',
#  '[우리는 오늘부터]\n이마이...매력적이야',
#  '[우리는 오늘부터]\n바보라서 다행이다~',
#  '[우리는 오늘부터]\n웃겨서화남',
#  '[우리는 오늘부터]\n바보라서 다행이다~ㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '[우리는 오늘부터]\n오마이갓^^ 미츠하시랑 이토랑 이마이랑 좋아졌어',
#  '[우리는 오늘부터]\n가볍게… 귀엽다.',
#  '[우리는 오늘부터]\n싱긋(^ㅁ^)',
#  '[우리는 오늘부터]\n산뜻해보이는 이마이가 열받네',
#  '[우리는 오늘부터]\n이마이 바보인데 .. 좋다',
#  '[우리는 오늘부터]\n배우들 웃참이 다했다',
#  '[우리는 오늘부터]\n웃음 참는거 개웃김',
#  '[우리는 오늘부터]\n유치한데 재밌고 유쾌함! 그냥 미츠하시 캐릭터가 살짝 재수는 없어도 미워보이진 않고 이마이 당신은 그저 쿨해 그의 미소는 잊혀지지 않는다',
#  '[우리는 오늘부터]\n이마이 한테 스며듬',
#  '[우리는 오늘부터]\n이마이... 행복하자',
#  '[우리들의 블루스]\n윗도리 아랫도리 어떻게 안웃어요 ㅠㅋㅋㅋㅋㅋㅋ',
#  '[우리들의 블루스]\n가까이 있는 삶인 척하기',
#  '[우아한 가]\n뭔가 통쾌한척하지만 답~~답',
#  '[우아한 가]\n짜릿해',
#  '[우아한 가]\n아무생각 없이 재미나게 봤음',
#  '[우아한 가]\n막장인데 통쾌하다',
#  '[운명과 분노]\n굿 아주재미있어요',
#  '[운명처럼 널 사랑해]\n두 배우의 케미가 나쁘지 않았던. 웃기기도 하고, 설레기도 하고.',
#  '[운명처럼 널 사랑해]\n사용된 음악들이 너무 좋다.',
#  '[원 더 우먼]\n유치찬란한데 그맛이 썩 나쁘진 않았음.',
#  '[원 더 우먼]\n아무생각없이 유쾌하게 볼 수 있어서 챙겨보는 중',
#  '[원 더 우먼]\n참지 않고 속시원히 자기 할 말 다 하는 주인공을 보며 느끼는 희열',
#  '[원 더 우먼]\n간만에 깔끔한 드라마',
#  '[원 더 우먼]\n추리가 필요없다. 그냥 그 시원함? 코믹? 그것만 누리면 된다. 이하늬면 설명이 충분했다',
#  '[원 더 우먼]\n아 시원해',
#  '[원 더 우먼]\n그래 제발 코미디 드라마도 좀 많이 만들어줘라',
#  '[원 더 우먼]\n보면 너무 사이다라 그간 쌓인거 다풀림 너무 웃김ㅋㅋㅋㅋㅋㅋ',
#  '[원티드]\n액션을 과시하기 바쁘다',
#  '[월간 집]\n이건 시리즈로 나와줘야 하는 코미디',
#  '[월간 집]\n뭔가 이번 생은 처음이라 와 비슷한 너낌',
#  '[월간 집]\n막 유쾌하기만 한 것은 아니지만, 부담없는 예능 드라마 느낌?',
#  '[월간 집]\n가볍게 보기 좋은 드라마',
#  '[월간 집]\n가난을 거꾸로 해보십시오! 난..가? 진짜 오바스럽고 명랑하고 재밌었는데 뭐하러 우울코드는 자꾸 넣어가지곤😞 꽁냥대기도 부족하구만',
#  '[유미의 세포들]\n보는동안 나를 아끼는 귀엽고 소중한 존재들이 갑자기 많아지는 느낌이 들었다. 그래서 때로는 신났고 때로는 안타까웠다.',
#  '[유미의 세포들]\n예상했지만 예상했던 결말로 끝나서 너무 좋다.',
#  '[유미의 세포들 2]\n보는동안 나를 아끼는 귀엽고 소중한 존재들이 갑자기 많아지는 느낌이 들었다. 그래서 때로는 신났고 때로는 안타까웠다.',
#  '[유미의 세포들 2]\n예상했지만 예상했던 결말로 끝나서 너무 좋다.',
#  '[으라차차 와이키키]\n소희연기땜에 몰입방해됨',
#  '[으라차차 와이키키]\n더 쎈 웃음이 필요했다',
#  '[으라차차 와이키키]\n억지 과장 헛웃음',
#  '[으라차차 와이키키]\n너무 뻔한 웃음',
#  '[으라차차 와이키키]\n의리로 본다 ..',
#  '[으라차차 와이키키]\n나도 저렇게 즐겁게 인생이 잘 풀리게되면 얼마나 좋을까 잘웃었다 (문가영 너무 예쁨)',
#  '[으라차차 와이키키]\n브라더.. 하고 개소리하는게 너무웃김 아 개웃겨',
#  '[으라차차 와이키키]\n은근 재밌음',
#  '[응답하라 1988]\n시청자우롱하니좋니^^',
#  '[응답하라 1988]\n익숙함에 속아 소중함을 잊지않기',
#  '[응답하라 1988]\n택이가 맞다니께 ^^',
#  '[이리와 안아줘]\n다름아 잘 커줘서 고마워ㅠㅠ',
#  '[이리와 안아줘]\n나무와 낙원의 위로가 따뜻하다',
#  '[이리와 안아줘]\n❣️',
#  '[이번 생은 처음이라]\n건투를 빕니다. 이번 생은 어차피 모두 처음이니까.',
#  '[이번 생은 처음이라]\n너무 현실적이고, 공감가는 대사들이 많다.',
#  '[이번 생은 처음이라]\n요즘 행복한 이유다',
#  '[이번 생은 처음이라]\n소소하게, 그러나 깊이 있게 위로가 된다.',
#  '[이브]\n헛웃음 나오는데 계속 보고있음',
#  '[이브]\n속삭이거나 소리지르거나',
#  '[이웃집 꽃미남]\n재미는 그냥 그런데 배우들 비주얼이 매우 맘에 듦',
#  '[이웃집 꽃미남]\n잔물결치는 드라마',
#  '[이웃집 꽃미남]\n생각보다 좋았다. 위로를 받는 느낌도 있었던것 같다.',
#  '[이웃집 꽃미남]\n소박하고 따뜻한척하는 것 같고 너무 잔잔했다. 악역이 악역이 아니고 연애가 연애가 아닌듯.',
#  '[이웃집 꽃미남]\n기억이 잘 안난다',
#  '[이웃집 꽃미남]\n어릴 때 재밌게 봤다',
#  '[이웃집 꽃미남]\n깨금이좋아',
#  '[이판사판]\n결국, 개판.',
#  '[이판사판]\n사건 전개가 느리다',
#  '[이판사판]\n힘들다',
#  '[이판사판]\n뭔가 하고 싶은 얘기는 많은데.. 그런 것 같은데..',
#  '[인간수업]\n평범이란 사치.',
#  '[인간수업]\n아슬아슬하게 불편하고, 시간 가는 줄 모르게 빠져든다.',
#  '[인현왕후의 남자]\n연애하고 싶게 말이야.',
#  '[인현왕후의 남자]\n재밌어요~ 두번이나 봤어요~',
#  '[일지매]\n다시봐도 재밌음...',
#  '[자이언트]\n사랑받는 자의 미소는 아름답다.',
#  '[자이언트]\n난 내가 선택한 대로 된다.',
#  '[작은 아씨들]\n이 정도면 책보다 재밌다! 베스 나오는 씬 마다 마음이 따뜻해짐',
#  '[작은 아씨들]\n.',
#  '[장난스런 키스]\n유쾌하고 따뜻한 인연 장난스러움이 진심으로 진화하는 과정 열 번 찍어 안 넘어가면 열 한 번 찍는, 독하지만 귀여운 끈기',
#  '[장난스런 키스]\n누군가는 설레면서 봤겠지.',
#  '[장난스런 키스]\n왜 때문인지 감동 받았습니다. 그리고 승리는 나쁩니다.',
#  '[장난스런 키스]\n와 끝까지 다 본 나에게 박수를..',
#  '[장난스런 키스]\n장난으로 만든 것 같은 영화.',
#  '[장난스런 키스]\n내가 재밌게 봤다는데 뭐',
#  '[장난스런 키스]\n날 위해 노력해 주는 네 모습이 귀여워 ‘',
#  '[장미빛 연인들]\n너무 재미있어요!!!!!',
#  '[장미빛 연인들]\n재미잇어요',
#  '[장옥정, 사랑에 살다]\n김태희 연기가 발전해서 내가괜히 뿌듯함..',
#  '[장옥정, 사랑에 살다]\n나의 인생 드라마.....근데 나만 그런 듯',
#  '[저글러스]\n백진희가 이리도 유쾌 화통할 줄이야.',
#  '[저글러스]\n뻔하지만 귀여움',
#  '[저글러스]\n비주얼 때문에 봤다',
#  '[저글러스]\n스트레스없이 가볍게 볼 수 있는 달달한 악역마저 웃긴',
#  '[저글러스]\n귀엽고 유치한',
#  '[저스티스]\n희망은 진실이며 현실이다.',
#  '[저스티스]\n응가하다가 끊긴 느낌이다... 개운하지는 않지만 더 보고 싶다.',
#  '[전설의 고향]\n새로운 아역발견 그리고 옛추억생성',
#  '[전설의 고향]\n쌍둥이 자매에 대한 내용. 근데. 재미가.',
#  '[전설의 고향]\nㅇㅇ',
#  '[전설의 고향]\n.',
#  '[전설의 고향]\n내가 이걸 내 돈 주고 봤다니',
#  '[전설의 마녀]\n뻔하다',
#  '[전설의 마녀]\n왠진 모르겠지만 그냥 뭔가 재미(는) 있다....',
#  '[전설의 마녀]\n소재만큼은 새로웠다',
#  '[전설의 마녀]\n얼탱이 없어서 웃겻다',
#  '[전설의 마녀]\n부족한 점 투성이지만 나도 뭔가 모르게 보고있었다',
#  '[전설의 마녀]\n엄마랑 같이 보기 딱좋았다 얘깃거리도 되고',
#  '[전설의 마녀]\n개잼ㅎㅎㅎㅎ완전잼',
#  '[전설의 마녀]\n넘 재미있어요~~잘보고 있습니다~~수인이가 잘되게 해주세요~~',
#  '[전우치]\n유쾌! 통쾌! 상쾌! 3박자를 고루갖춘 잼있는 액셩영화 굿굿',
#  '[전우치]\n그럭저럭 흥미진진',
#  '[전우치]\n영화의 독특한 분위기가 좋았다. 캐스팅 덕분인듯.',
#  "[전우치]\n신선한 장르, 매력적인 캐릭터, 흥미진진한 볼거리. '유쾌' 그 자체적인 모습.",
#  '[절대 그이]\n진구때문에 봤어요..',
#  '[절대 그이]\n개병맛인데 존나웃김ㅋㅋㅋㅋㅋㅋㅋ',
#  '[절대 그이]\nㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '[절대 그이]\n재밌게 했음 -기록용',
#  '[제3의 매력]\n가끔 또 보고싶을 것 같다.',
#  '[제3의 매력]\n중반까진 재밌게 봤다고.... 그랬다고... 하 ..',
#  '[제빵왕 김탁구]\n맛있구나, 탁구야.',
#  '[제빵왕 김탁구]\n맛있었던드라마.',
#  '[제빵왕 김탁구]\n자꾸 들려요... 그 사람아 사랑아 내 사랑아...',
#  '[제왕의 딸, 수백향]\n한편의 고전서사를 읽는듯한 묵직한 감동',
#  '[제왕의 딸, 수백향]\n수고했다.',
#  '[조선로코 녹두전]\n뭐야 ㅅ시불 재미있다고 하는거에 낚였네',
#  '[좀비탐정]\n뻔하고 유치한데 신선하고 웃기잖아.',
#  '[좀비탐정]\n흔한 B급 감성',
#  '[좋아하면 울리는]\n장난하나',
#  '[좋아하면 울리는]\n개노잼',
#  '[지금, 헤어지는 중입니다]\n쿨한척 하는 부장님이 떠오른다...',
#  '[지금, 헤어지는 중입니다]\n주변인물들 상황 대사가 참 현실적이어서 공감가네',
#  '[지금, 헤어지는 중입니다]\n어디에서 본거같아 사람만 달라진느낌..',
#  '[지금, 헤어지는 중입니다]\n이제 겁내지 않고 우리가 사랑했던 그대로, 그 힘으로, 나는 또 살아갈게.',
#  '[지금, 헤어지는 중입니다]\n뭐.. 난 재밌었음! ㅎㅎ',
#  '[지옥]\n중간에 띠용한 부분이 있긴 하지만 그래도 재밌었다',
#  '[지옥]\n콘셉트와 캐릭터에 잡아먹힌 메시지',
#  '[진심이 닿다]\n끝내 무심한 동정에 닿기까지.',
#  '[진심이 닿다]\n가벼운 로코물이지만 볼만하다.',
#  '[진심이 닿다]\n질질안끓어서좋아요 달달😊',
#  '[진심이 닿다]\n“저는 느린 사람이지만, 제 나름의 속도로 한 걸음씩 다가가겠습니다. 천천히, 오랫동안.”',
#  "[질투의 화신]\n조정석이 '더' 좋아지는 드라마.",
#  '[질투의 화신]\n매회 웃음 터짐 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '[질투의 화신]\n갈수록 이야기가 똥되는 느낌.',
#  '[찬란한 유산]\n선의는 돌아오는 거야.',
#  '[찬란한 유산]\n이런 분위기 좋아요.',
#  '[천국의 계단]\n생각보다 신선하고 유머러스했던.',
#  '[천국의 계단]\n재미난 상상력과 표현으로 빚어낸 멜로드라마.',
#  '[천국의 계단]\n카메라는 답을 알고 있다',
#  '[천국의 계단]\n무슨 이런 달콤한 이야기가',
#  '[천국의 계단]\nㅇ',
#  '[천국의 계단]\n시대가 믿기지 않는다.',
#  '[천원짜리 변호사]\n코미디였네',
#  '[천원짜리 변호사]\n백시보 괜찮네~~',
#  '[천원짜리 변호사]\n유치해서 소리 지르면서 봤지만 많이 웃었음 😆',
#  '[천원짜리 변호사]\n그럭저럭, 얼렁뚱땅. 재미는 있다.',
#  '[천원짜리 변호사]\n어디서 본 듯한 스토리',
#  '[천원짜리 변호사]\n3번째 웃으면 저랑 사귈래요?',
#  '[철인왕후]\n다들 행복해 보여서 나도 행복했다.',
#  '[철인왕후]\n본편 이전 이야기를 담아 재밌다. 아쉬움을 좀 덜어줌.',
#  '[철인왕후]\n재밌었다...',
#  '[철인왕후]\n재미있게 보고있습니당 ㅋㅋ 가끔 현웃포인트가 있음',
#  '[철인왕후]\n본편과 무관하여 좋다.',
#  '[첫사랑은 처음이라서]\n딱 알맞게 잘 만들어 진 드라마였다 ㅎ',
#  '[첫사랑은 처음이라서]\n뭐냐... 재미없다',
#  '[첫사랑은 처음이라서]\n재밌듬',
#  '[첫사랑은 처음이라서]\nㅋㅋ 개노잼',
#  '[청춘기록]\n마음이 움직이는 드라마..',
#  '[청춘기록]\n오랜만에 너무 재밌다..!!',
#  '[청춘기록]\n즐거운 얼굴 보검이 보는중',
#  '[초면에 사랑합니다]\n뻔해서 좋았던',
#  '[초면에 사랑합니다]\n스트레스 팍팍풀리는 대리만족의 향연.',
#  '[초면에 사랑합니다]\n뷰티인사이드같은 내용같으면서도 한 사람은 보이는 소재를 넣어 비서와의 관계가 가까워지며 사랑을 하는 그런 내용이여서 재밌었다',
#  '[초면에 사랑합니다]\n영광입니당ㅋㅋㅋㅋㅋ',
#  '[초콜릿]\n아날로그의 달콤함에 기분 좋아진다.',
#  '[초콜릿]\n기묘하고 그로테스크한 느낌이 좋았다.',
#  '[초콜릿]\n어린이들의 꿈과 희망, 어른들의 어린이들에 대한 꿈과 희망.',
#  '[초콜릿]\n어른들에게는 동심을 아이들에게는 희망을.',
#  '[초콜릿]\n행복으로 버무려진 달콤한 초콜릿.',
#  '[최강 배달꾼]\n이드라마를 보면서 대리만족의 시간을 가졌다.',
#  '[최강 배달꾼]\n뻔할 수도 있지만 뻔하지 않고 신선한 면들이 많다',
#  '[추노]\n스타일리쉬한 연출과 긴박감. 그리고 적절한 유머와 감동.',
#  '[추리의 여왕]\n전편처럼 재미졌으 ㅎ',
#  '[추리의 여왕]\n이렇게 코믹하면서 케미 좋은 드라마 또 안나오나',
#  '[추리의 여왕]\n가볍게 좀더 가볍게 가즈아~ 시즌3',
#  '[추리의 여왕]\n빠른 전개 굿굿',
#  '[친애하는 판사님께]\n다 접어두고.. 일단 내 취향에, 재미지다~',
#  '[친애하는 판사님께]\n대리만족. 사이다 원샷.',
#  '[컬러 러쉬]\nㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '[컬러 러쉬]\nㅇㅇ',
#  '[컬러 러쉬]\n멋있고 재미있다👍👍👍',
#  '[컬러 러쉬]\n킹받는다...',
#  '[컬러 러쉬]\n너무 나빠서 나 웃었어',
#  '[컬러 러쉬]\n넷플릭스에 있길래 봤는데 낚였다',
#  '[쾌걸 춘향]\n웃기시네 신경끄셔',
#  '[쾌걸 춘향]\n음악도 좋고 내용도 은근 재미있었다.',
#  '[쾌걸 춘향]\n현대판 각색에 흥미로움 갖음.',
#  '[쾌걸 춘향]\n행복하길바래……',
#  '[쾌걸 춘향]\n옛날에봤던거인데도지금도생각난다:)재밌다',
#  '[쾌걸 춘향]\n유치해도 재밌는데',
#  '[크레이지 러브]\n킬링타임용 가볍게 감상',
#  '[크로스]\n- 익숙함을 넘어 날아올라 멈추지 않고 달린다',
#  '[킬미, 힐미]\n바람이 분다. 살아야겠다.',
#  '[킬미, 힐미]\n상처를 갖고 살아가는 세상 모든 사람들에게 토닥이듯이 건네는 따스한 위로.',
#  '[킬미, 힐미]\n정신과적 해석이 매우 훌륭했음',
#  '[킬힐]\n여자들 기싸움이라 진부하지만 재밌네.',
#  '[타임즈]\n장황하지만 보는 재미가 있고 재미있지만 어디선가 본 거 같고',
#  '[타임즈]\n어디서 많이 본 듯한 신선함',
#  '[타임즈]\n두 가지가 보인다.',
#  '[태양의 후예]\n그냥...설렜다....ㅎ',
#  '[태양의 후예]\n인소가 이거보단 낫겠다. 환장할 지경.',
#  '[태조 왕건]\n궁예 얼굴만 봐도 웃김ㅋㅋ',
#  '[태조 왕건]\n덕분에 힘찬 국사시간을 보낸 느낌...',
#  '[투제니]\n깨끗하게 설레게 하네',
#  '[투제니]\n뻔하고 서툰 듯 해도 마음이 동하는 진심.',
#  '[투제니]\n재밌네 법자탈출',
#  '[투제니]\n기분 좋은 드라마',
#  '[투제니]\n캐스팅이 적절하다.',
#  '[투제니]\n❤️',
#  '[투제니]\n음악이 좋음',
#  '[펜트하우스 2]\n벌써 떨리는군...^^',
#  '[펜트하우스 2]\n꾸준하다 못해 특색있다 느껴진다.',
#  '[펜트하우스 2]\n시즌1에 비해 더 한 자극. 자극성에 속도감까지 더해져서 흡입력이 나아졌다.',
#  '[펜트하우스 2]\n욕하면서 보는 맛.',
#  '[펜트하우스 3]\n적당히 해라',
#  '[포레스트]\n포레스트는 내 마음속  가장자리 어딘가에서 뛰고있다 묵묵히',
#  '[포레스트]\n"너랑 같이 있었더라면 좋았을텐데." "같이 있었어. 제니."',
#  '[포레스트]\n살면서 영화를 본다는 것의 행복',
#  '[포레스트]\n믿고 싶은 주인공이 들려주는 믿기 힘든 이야기.',
#  '[포레스트]\n영화가 좋은 이유.. 마음이 몽글몽글하다',
#  '[푸른 바다의 전설]\n재밌다!그냥재밌다 너무유쾌하다',
#  '[푸른 바다의 전설]\n뻔한데 유치한데  예쁨',
#  '[푸른 바다의 전설]\n재미있었다👍',
#  '[푸른 바다의 전설]\n유치하다고 할 수도 있겠지만 난 재밌었다 갓지현 😍',
#  '[풍선껌]\n두고 두고 둘 , 이야기',
#  '[풍선껌]\n보면서 공감하고 마음으로 느끼며 배우와 같이 눈물이 나는 그런 Best',
#  '[풍선껌]\n행복했다 나 그대들을 만나서, 내가 사랑하는 사람들에게',
#  '[프라하의 연인]\n역시 다시 봐도 재밌음',
#  '[프라하의 연인]\nOst랑 분위기 찰떡',
#  '[프라하의 연인]\n숨겨지지 않는 날 것의 감정들',
#  '[프라하의 연인]\n전도연 좋아~',
#  '[프라하의 연인]\n애절하다.',
#  '[하나뿐인 내편]\n엄마랑 봐야 재밌다',
#  '[하나뿐인 내편]\n꿀잼',
#  '[하나뿐인 내편]\n스트레스 받고 싶으면 추천',
#  '[하이드 지킬, 나]\n재밌는데 가끔 엥스러움',
#  '[하이드 지킬, 나]\n여, 남주 비주얼이 다 했다.',
#  '[하이바이, 마마!]\n과정이나 결말이 어찌됐든 눈물이 주륵주륵ㅜㅜ',
#  '[하이바이, 마마!]\n시작은 좋았는데...',
#  '[하이바이, 마마!]\n가슴이 아프다',
#  '[하이바이, 마마!]\n배우들의 감정연기는 참 좋다만.',
#  '[학교 2017]\n재미있고 주인공이 연기를잘한다',
#  '[학교 2017]\n그냥 뭐 귀여웠음',
#  '[학교 2017]\n세정이 화이팅',
#  '[학교 2017]\n귀여운 섹스한 모습에 반했다',
#  '[학교 2021]\n서브 케미 때문에 봤다. 개노잼',
#  '[한 번 다녀왔습니다]\n요즘 열심히 챙겨보는 중이다. 가족들 하나같이 귀엽고 매력있다.',
#  '[한 번 다녀왔습니다]\n내가 행복해야 세상도 아릅답다😊',
#  '[함부로 애틋하게]\n김우빈의 섬세한 감정선에 놀람... 그래서 그런지 뻔한스토리임에도 잔잔한 느낌을준다. 보기 편안하다.',
#  '[해치]\n실소로 시작해서 미소로 매듭짓는 무공해 코미디.',
#  '[해치]\n산만하고 둔하다.',
#  '[해치]\n신선한 소재와 초중반 웃음 타율은 좋지만 웃음, 감동, 메시지를 다 잡으려니 이도 저도 아닌.',
#  '[해치]\n웃으며 입장, 산뜻하게 관람, 헛헛하게 퇴장.',
#  '[해치]\n아이들의 청명한 웃음소리가 예뻤다 무표정했던 어른들에게  우리가 뭔가 놓쳐왔는가 생각하게 만들기 충분했다',
#  '[해치]\n재미가 없는 건 아닌데 루즈한 부분도 없지 않은 애매모호함.',
#  '[해치]\n웃음 포인트는 진지함 진지함 속에 터져 나오는 웃음 나쁘지 않아',
#  '[해치]\n“순해서 좋아” 한국 코미디는 신선하면서도 친숙해야 한다',
#  '[해치]\n꼬맹이들 리액션 들으면서 같이 보니깐 재밌다,,, 내적친목,,,,',
#  '[해치]\n기분좋게 살랑이는 코미디',
#  '[해치]\n웃기진 않아 나쁘진 않아 신선하진 않아 ㅋㅋㅋㅋㅋ',
#  '[해치]\n개연성에서도 포스터처럼 당당해지고픈 코미디.',
#  '[호텔 델루나]\n지은이가 개연성이고 줄거리고 CG고 재미지.. 뭐..',
#  '[호텔 델루나]\n“부디 언젠가는 당신의 시간이 다시 흐르길  바랍니다.”',
#  '[호텔 델루나]\n후반갈수록 빨리넘기면서봤네요 오글거림에 약해서.. 한회 한회 옴니버스식 귀신(직원포함) 스토리가 좋았습니다',
#  '[호텔킹]\n둘이 썸 탈때가 좋았음.',
#  '[호텔킹]\n난 나름 재밌게본듯',
#  '[호텔킹]\n재밌엇어요',
#  '[홍천기]\n하람이 미소 랑 낮은 저음 극락가넼ㅌㅌㅌㅌ 🤭😍',
#  '[홍천기]\n의리로 보는중',
#  '[홍천기]\n가끔은 유치한 것도 좋다.',
#  '[홍천기]\n재밌듬',
#  '[홍천기]\n얼굴 구경 실컷 했습니다',
#  '[화랑]\n우리엄마가  즐겨보셨음.',
#  '[화랑]\n재미없다 재미없다 하다가 끝을 봤네... 만세!',
#  '[화랑]\n15화가 재밌습니다',
#  '[화랑]\n다시보면내가호구ㅅㄲ다',
#  '[화랑]\n뭔가 아쉬운..ㅠ',
#  '[화랑]\n재밌었다',
#  '[화양연화]\n더 없는 마음이지만 신에게 예를 드릴 때처럼 조용히 다녀갑니다. 가져간 덧신 신고 있어요',
#  '[화양연화]\n세련되고 또렷하며 섬세하다',
#  '[화유기]\n점점 뭘 하려는건지 모르겠다.',
#  '[화유기]\n아 재밌어 자존심상해 화깨비주제에',
#  '[환혼]\n해피엔딩으로 끝내주셔서 감사하고 소중합니다 🙏',
#  '[황후의 품격]\n재밌는데 왜ㅋㅋㅋㅋㅋㅋㅋ개웃김',
#  '[황후의 품격]\n전개가 빠르고 흡입력이 강함',
#  '[황후의 품격]\n미침.',
#  '[황후의 품격]\n막장인데 재밌어',
#  '[훈남정음]\n코믹이 과하다 했소이다. 201807',
#  '[훈남정음]\n난 재밌었는데...역시 드라마는 직접 봐야 알 수 있다',
#  '[흑기사]\n유쾌해서 좋다. 있던 걱정들도 모두 떨쳐낼 수 있게 해줘서 고마워.',
#  '[흑기사]\n재미는 원시시대급이네.',
#  '[흑기사]\n지금이라도 채널 돌리다가 케이블에서 하고있다면 다시 한 번 재미있게 볼 수 있는 유쾌한 영화.',
#  '[흑기사]\n그의 얼굴만 봐도 웃음이 나온다.',
#  '[흑기사]\n코미디인데 왜 웃기질 못해',
#  "[흑기사]\n가볍지만 신박한 리얼 '블랙'코미디.",
#  '[흑기사]\n뻔뻔할 만큼 의미 찾을 필요 없는 영화라 가벼워서 보기 편하다.',
#  '[흑기사]\n스테레오타입과 클리셰를 멋지게 가지고 노는 코메디.',
#  '[흑기사]\n가볍게 즐길수잇다 나쁘지않다',
#  '[흑기사]\n그냥 짬날때보면 재밋는 코미디',
#  '[흑기사]\n유쾌하다',
#  '[흑기사]\n최고의 코미디',
#  '[흑기사]\n간단하고 유쾌하면서 웃기 좋은 영화',
#  '[흑기사]\n코믹함. 마틴 로맨스가 멍청해 보여도 할 건 다 함..',
#  '[흑기사]\n말투부터 표정까지 코메디 그 자체',
#  '[힐러]\n진짜 날 힐링시켜줬어',
#  '[힐러]\n진짜꿀잼',
#  '[힘쎈여자 도봉순]\n취향저격❤',
#  '[D.P.]\n이야기는 커졌지만, 밀도가 사라진..',
#  '[SF8]\n<보는중>간호중 너무 괜찮음',
#  '[SF8]\n와 괜찮다!',
#  '[SF8]\n"시도는 좋았다"와 "다음 시즌이 기대된다" 중간 어디쯤에.',
#  '[SKY 캐슬]\n공감되는것도 있구 재밌게 봤는데 ㅋㅋ 마지막에 뭐람 ㅋㅋㅋㅋ',
#  '[SKY 캐슬]\n기빨려..']

# %%
# 6. 결과 저장
filtered_path = "/content/drive/MyDrive/문화data/Ontology_filtered_reviews2.txt"
with open(filtered_path, 'w', encoding='utf-8') as f:
    for review in filtered_reviews:
        f.write(review + '\n')
print('저장 완료:', filtered_path)
# Out:
# 저장 완료: /content/drive/MyDrive/문화data/Ontology_filtered_reviews2.txt
